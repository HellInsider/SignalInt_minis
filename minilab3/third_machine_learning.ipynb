# %% [markdown]
# # Третья лабораторная. Методы машинного обучения
#
# Лабораторная состоит из гайда по методам глубинного обучения (Deep Learning) и "продвинутым" методам машинного обучения (Machine Learning) на Python и пяти заданий:
#
# * [Задание 1](#Задание-1.) - поиск гиперпараметров случайного леса
#
# * [Задание 2](#Задание-2.) - поиск гиперпараметров нейросети для классификации
#
# * [Задание 3](#Задание-3.) - поиск гиперпараметров для градиентного бустинга
#
# * [Задание 4 (дополнительное)](#Задание-4-(дополнительное).) - выбор подходящих аугментаций. Это задание повышенной сложности, за него даётся 3 балла
#
# * [Задание 5 (дополнительное)](#Задание-5-(дополнительное).) - выбор модели машинного обучения для решения задачи регрессии. За это задание можно получить 1 балл
#
# Из пяти заданий требуется выполнить минимум первые 3 задания, за остальные задания можно заработать дополнительные баллы.
#
# За попадание в топ 3 по качеству модели в заданиях 3, 4 и 5 можно получить по 1 дополнительному баллу за задание.
#
# Задания 2, 3 и 4 последовательно связаны друг с другом - для одной задачи требуется добиться необходимого качества разными способами. Чтобы выполнить задание 3, требуется сначала выполнить задание 2, так как там обучается нейросеть для предобработки (имейте это в виду, если будете перезапускать ноутбук).

# %% [markdown]
# *В этом ноутбуке изначально опущены результаты исполнения кода. Рекомендуется запускать (Shift+Enter) ячейки по мере просмотра документа*

# %% [markdown]
# ---
#
# ## Введение
#
# Центральное понятие в машинном обучении - **модель**. Задачей машинного обучения является создание (обучение) модели, максимально <u>качественно</u> описывающей обучающие <u>данные</u>. Цель - получить модель, способную делать полезные предсказания по новым данным.
#
# При этом критерии <u>качества</u> могут быть различными, и сильно влияют на результирующую модель. Определить *идеальный критерий*, подходящий для любого случая сложно (или невозможно). Это обусловлено как минимум двумя проблемами:
# * Данные частично некорректны - содержат шум и выбросы.
#     Шум возникает, например, из-за неточности измерений, а выбросы - чаще из-за ошибок;
# * Данные могут быть неполны - не полностью отражать действительность.
#
# Для получения полезной с практической точки зрения модели, надо учитывать, что обучающие данные (training set) могут отличаться от данных, на которых требуется вычислять предсказания (evaluation / test set).
#
#
# Как правило задачи машинного обучения разделяют на две категории:
#
# **1. [Обучение без учителя](https://scikit-learn.org/stable/unsupervised_learning.html)**
#
# * [Кластеризация](https://scikit-learn.org/stable/modules/clustering.html);
# * [Поиск ассоциативных правил](https://ru.wikipedia.org/wiki/Обучение_ассоциативным_правилам);
# * [Понижение размерности](https://scikit-learn.org/stable/modules/unsupervised_reduction.html);
# * [Поиск выбросов](https://scikit-learn.org/stable/modules/outlier_detection.html).
#
# **2. [Обучение с учителем](https://scikit-learn.org/stable/supervised_learning.html)**
#
# * [Классификация](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html);
# * Регрессия;
# * Ранжирование;
# * [Анализ выживаемости / рисков](https://nbviewer.jupyter.org/github/sebp/scikit-survival/blob/master/examples/00-introduction.ipynb).
#
# Но также есть множество задач, не вписывающихся в эти категории, например:
#
# * Multiple-instance Learning - целевые значения сопоставлены группам (bag) наблюдений;
# * One-shot Learning - классификация с одним обучающим примером для каждого класса;
# * Similarity Learning - поиск меры схожести объектов;
# * Reinforcement Learning - обучение модели, совершающей действия в ходе взаимодействия со средой;
# * Collaborative Filtering - построение рекомендаций;
# * Natural Language Processing: машинный перевод, QA - получение текстового ответа на текстовый вопрос;
# * Перенос стиля, генерирование изображений.
#
# Поэтому перед созданием модели лучше не сразу пытаться свести задачу к базовым задачам машинного обучения (классификации, регрессии), а поискать модели, использующие специфику области. Например, для машинного перевода специфичен порядок слов в предложении, и правильных переводов может быть несколько - решение задачи без использования этих особенностей приводит к крайне плохим результатам.

# %% [markdown]
# ### Overfitting / Underfitting
#
# Чтобы полученная модель была практически применима, надо соблюсти баланс между переобучением (overfitting) и недообучением (underfitting):
# * переобучение возникает, когда модель имеет минимальную ошибку на обучающем множестве, и значительно большую на тестовом;
# * недообучение возникает при использовании слишком простых моделей, которые не могут обеспечить достаточно маленькую среднюю ошибку даже на тренировочных данных.
#
# В качестве примера рассмотрим задачу одномерной регрессии с синтетическими данными:
#
# Обучающее множество: $\{(x_i, y_i)\}_{i=1}^{n}$,
# где $x_i$ - наблюдения $x \sim U([0; 1]); \varepsilon \sim N(0, 0.1)$,
# $y = f(x) + \varepsilon$,
#
# $f(x) = \cos(5 x + \frac{\pi}{2})$
#
# Для простоты будем использовать полиномиальную модель:

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(239)

def f(x):
    return np.cos(x * 5 + np.pi/2)

X = np.sort(np.random.rand(20))
y = f(X) + np.random.normal(0, 0.1, len(X))

fig, ax = plt.subplots(1, 3, figsize=(15, 4))
X_lin = np.linspace(0, 1, 50)  # массив 50 чисел от 0 до 1
titles = ["Underfit. Degree = 2", "Best fit. Degree = 4", "Overfit. Degree = 12"]
for i, title in enumerate(titles):
    ax[i].set_title(title)
    ax[i].scatter(X, y)  # наблюдения
    ax[i].plot(X_lin, f(X_lin), color='g')  # целевая функция
# модель - полином, подбор коэффициентов - МНК
predictor_underfit = np.poly1d(np.polyfit(X, y, deg=2))
ax[0].plot(X_lin, predictor_underfit(X_lin))

predictor_best = np.poly1d(np.polyfit(X, y, deg=4))
ax[1].plot(X_lin, predictor_best(X_lin))
ax[1].plot(X_lin, f(X_lin), color='g')

predictor_overfit = np.poly1d(np.polyfit(X, y, deg=12))
ax[2].plot(X_lin, predictor_overfit(X_lin))
ax[2].plot(X_lin, f(X_lin), color='g')

ax[0].legend(["f(x)", "Prediction", "Observation"])

plt.show()

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
tf.device('/device:GPU:0')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11763156320507151315
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2256220980
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7919537780473405192
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %% [markdown]
# Заметим, что третий вариант аппроксимации функции (с переобучением) очевидно не может быть использован на практике. Как минимум, из-за слишком больших значений в промежутке от 0 до 0.1.
#
# Однако о первом варианте (с недообучением) такого сказать нельзя. Хотя полученная функция не совпадает с $f(x)$, она достаточно неплохо оценивает обучающее множество. На практике при малом числе наблюдений и большой размерности пространства сложные модели скорей всего будут склонны к переобучению, тогда как простые, вроде линейной регрессии, будут давать хоть насколько-то верную аппрокимацию.
#
# Посмотрим на ошибки в данном примере на обучающем множестве:

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def print_err(title, model, x, y_true):
    mse = mean_squared_error(y_true, model(x))
    mae = mean_absolute_error(y_true, model(x))
    r2  = r2_score(y_true, model(x))
    print(title)
    print(f"MSE: {mse:.3f}, MAE: {mae:.3f}, R^2: {r2:.3f}\n")

for i, model in enumerate([predictor_underfit, predictor_best, predictor_overfit]):
    print_err(titles[i], model, X, y)
# Out:
# Underfit. Degree = 2
# MSE: 0.060, MAE: 0.206, R^2: 0.894
#
# Best fit. Degree = 4
# MSE: 0.007, MAE: 0.068, R^2: 0.987
#
# Overfit. Degree = 12
# MSE: 0.005, MAE: 0.045, R^2: 0.992

# %% [markdown]
# Здесь $R^2$ - это коэффициент детерминации. Его множество значений от $-\infty$ до $1$.
#
# Эти значения ошибок показывают насколько хорошо модель смогла запомнить обучающие данные.
#
# Попробуем применить модель к новым данным:

# %%
X_test = np.sort(np.random.rand(200))
y_test = f(X_test) + np.random.normal(0, 0.1, len(X_test))

for i, model in enumerate([predictor_underfit, predictor_best, predictor_overfit]):
    print_err(titles[i], model, X_test, y_test)
# Out:
# Underfit. Degree = 2
# MSE: 0.060, MAE: 0.205, R^2: 0.887
#
# Best fit. Degree = 4
# MSE: 0.010, MAE: 0.079, R^2: 0.982
#
# Overfit. Degree = 12
# MSE: 0.527, MAE: 0.335, R^2: 0.007

# %% [markdown]
# Видно, что качество предсказания первых двух моделей почти не упало, когда как третья (переобученная) даёт ошибку на два порядка больше. Таким образом можно выбрать наиболее корректную модель.
#
# Формально, разность между риском (математическим ожиданием ошибки) и эмпирическим риском (средним значением ошибки на обучающем множестве), называется **переобученностью**.
#
# В примере мы смогли **сгенерировать** новый набор данных, на котором проверяли насколько хорошо подходит модель, **приближая** значение переобученности (вместо математического ожидания ошибки мы вычисляли среднюю, но **не** на обучающем множестве). На практике сгенерировать новый набор данных может быть трудоёмко, или вообще невозможно, поэтому нужно уметь оценивать модель, имея только один (тренировочный) набор данных. Но как?

# %% [markdown]
# ### Кросс-валидация (Cross-Validation)
#
# Для того, чтобы понять насколько хорошо подходит модель, воспользуемся [перекрёстной проверкой](https://ru.wikipedia.org/wiki/Перекрёстная_проверка) на имеющихся обучающих данных: будем обучать модель $k$ раз, каждый раз выделяя $k-1$ долей обучающего множества для обучения модели (с нуля), используя оставшуюся долю для оценки качества. Это позволит оценить не только качество модели, но и чувствительность к обучающим данным, причём численно.
#
# Часто модели имеют гиперпараметры (параметры, значения которых фиксируются до начала обучения, например количество слоёв в нейронной сети). В примере выше гиперпараметр - это степень полинома. Подберём оптимальные гиперпараметры с помощью C-V. Для этого можно воспользоваться одной из следующих готовых реализаций:
# * [Grid-search C-V](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) - перебор значений гиперпараметров на некоторой сетке;
# * [Randomized search C-V](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) - перебор случайных значений гиперпараметров;
# * [Bayesian C-V](https://scikit-optimize.github.io/notebooks/bayesian-optimization.html) - перебор значений гиперпараметров, используя модифицируемое по ходу представление о форме поверхности ошибки. Реализован в библиотеке [hyperopt](https://hyperopt.github.io/hyperopt/).
#
# Наиболее популярный на данный момент метод - Bayesian C-V, но для простоты рассмотрим классический Grid-search C-V:

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# полиномиальный регрессор - то же самое, что линейная регрессия с признаками (x^0, x^1, x^2, ..., x^k)
polynomial_regressor = make_pipeline(PolynomialFeatures(), LinearRegression())
# сетка параметров степени полинома - целые значения от 0 до 14:
parameters = {'polynomialfeatures__degree': range(15)}

# scoring - минимизируемая метрика: https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
search = GridSearchCV(polynomial_regressor, parameters, cv=5, scoring='neg_mean_squared_error')
search.fit(X[:, np.newaxis], y)
print(f"Best loss (-MSE): {search.best_score_}")
print(f"Best parameters: {search.best_params_}")
# Out:
# Best loss (-MSE): -0.13969269572703555
# Best parameters: {'polynomialfeatures__degree': 5}

# %% [markdown]
# Проблему переобучения также можно решать с помощью регуляризации (например, в случае линейных моделей – Lasso, Ridge). При этом возникают дополнительные параметры, которые имеет смысл также перебирать с помощью кросс-валидации.

# %% [markdown]
# ## Продвинутые методы машинного обучения
#
# ### Ансамблевые методы
#
# Основная идея ансамблевых методов заключается в построении набора различных примитивных базовых моделей и использовании их комбинации для предсказаний.
#
# Это позволяет бороться с двумя проблемами:
# 1. Переобучение - за счёт различия моделей (структуры или данных, на которых модели обучаются);
# 2. Низкое качество предсказаний - для большинства моделей за счёт т.н. "мудрости толпы".
#
# В качестве базовых моделей могут использоваться любые методы, от линейной регрессии до нейронных сетей, однако стоит учитывать, что:
# * время построения ансамбля сложных моделей будет очень велико. Простые же модели можно строить параллельно;
# * на [bias-variance trade-off](https://habr.com/ru/company/ods/blog/323890/#razlozhenie-oshibki-na-smeschenie-i-razbros-bias-variance-decomposition) влияет сложность каждой базовой модели и их количество. Наиболее сложные базовые модели не всегда позволяют получать лучшее качество.
#
# #### 1. Случайный лес
#
# Случайный лес - ансамбль решающих деревьев (построенных по CART). Финальный прогноз производится усреднением результатов работы каждого дерева.
#
# Для получения различных деревьев используются два принципа:
# * Bagging (Bootstrap aggregation) - выборка для каждого дерева формируется случайным образом (с возвратом) из тренировочной. Методы, использующие bagging всегда могут оценивать ошибку на "out of bag" элементах начальной выборки - тех, что не вошли ни в одну из подвыборок;
# * Random feature subspace - в качестве признаков каждое дерево рассматривает случайное подмножество исходных признаков.
#
# Одним из основных преимуществ случайных лесов для классификации является возможность предсказать не только класс, но и "уверенность" - аппроксимацию вероятности данного класса при условии входных данных. Также они могут применяться для подбора наиболее релевантных признаков - т.н. feature importances.
#
# Рассмотрим простую задачу регрессии Boston House Prices:

# %%
from sklearn.datasets import load_boston

boston = load_boston(return_X_y=True)

# %% [markdown]
# Все признаки в этом датасете численные. Требуется научиться предсказывать цену дома по его параметрам.
#
# Взглянем на датасет. Понизим размерность с помощью [T-SNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html), [PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) и [Spectral Embedding](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.SpectralEmbedding.html), и поставим цвет, соответствующий значению $y$:

# %%
from sklearn.manifold import TSNE, SpectralEmbedding
from sklearn.decomposition import PCA

boston_X, boston_y = boston

xy = []
xy.append(TSNE(n_components=2).fit_transform(boston_X))
xy.append(SpectralEmbedding(n_components=2).fit_transform(boston_X))
xy.append(PCA(n_components=2).fit_transform(boston_X))

titles = ['T-SNE', 'Spectral Embedding', 'PCA']
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
for i, data in enumerate(xy):
    cx = ax[i].scatter(data[:, 0], data[:, 1], c=boston_y, cmap='rainbow')
    ax[i].set_title(titles[i])
omit = fig.colorbar(cx)

# %% [markdown]
# ---
#
# #### Задание 1.
#
# В коде ниже приведён пример запуска `RandomForestRegressor`.
#
# Требуется подобрать параметры (кроме `random_state` и `oob_score`) у `RandomForestRegressor`, чтобы [коэффициент детерминации $R^2$](http://www.machinelearning.ru/wiki/index.php?title=Коэффициент_детерминации) (оценка качетва) увеличился на **тестовых данных**, желательно до $0.85$.
#
# _В этом задании и последующих рекомендуется использовать автоматический подбор гиперпараметров вместо того, чтобы подбирать гиперпараметры вручную после каждого обучения модели, которая не смогла достичь требуемого качества._

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score


def model_score(X, y, estimator=None, cv=3, scoring=None):
    scores = cross_val_score(estimator, X, y, cv=cv, scoring=scoring)
    return np.mean(scores)



X_train, X_test, y_train, y_test = train_test_split(boston_X, boston_y, test_size=0.25, random_state=12345)

# Ваши значения параметров:
boston_rf = RandomForestRegressor(n_estimators=75,
                                  max_features='sqrt',
                                  min_samples_split=5,
                                  min_samples_leaf=1,
                                  criterion='mse',
                                  
                                  random_state=12345,  # `random_state` оставьте зафиксированным, чтобы можно было
                                                       # повторить ваш результат
                                  oob_score=True)
boston_rf.fit(X_train, y_train)

cv_score = model_score(X_train, y_train, estimator=boston_rf, cv=10, scoring='r2')
train_score = boston_rf.score(X_train, y_train)
test_score = boston_rf.score(X_test, y_test)
oob_score = boston_rf.oob_score_
print("Score (R^2) on train:")
print(f"Out of bag training score estimation: {oob_score}")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Score (R^2) on train:
# Out of bag training score estimation: 0.8666598023432506
# Cross-validation on train score: 0.8580195023357329
# Train score: 0.9701301340899481
# Test score: 0.8511735694344069

# %% [markdown]
# ---
#
# Ещё одной интересной особенностью ансамблей деревьев является возможность подсчитать "*важность*" признаков. Сделаем это для датасета boston:

# %%
importances = boston_rf.feature_importances_

# достанем названия признаков:
boston_annotation = load_boston()
feature_names = boston_annotation.feature_names
# описания признаков:
descriptions = [val for val in boston_annotation.DESCR.split("\n")
                    if val.find("        -") >= 0]
feature_descriptions = {feature: feature.join(desc.split(feature)[1:])
                        for desc in descriptions
                        for feature in feature_names if desc.find(feature) >= 0}

ind = np.argsort(importances)

plt.figure(figsize=(15, 5))
plt.bar(feature_names[ind], importances[ind])
plt.title("Feature importances")

top_features = list(feature_names[ind][:-4:-1])
print("Топ 3 важных признаков:")
print("\n".join([feature + feature_descriptions[feature] for feature in top_features]))
# Out:
# Топ 3 важных признаков:
# RM       average number of rooms per dwelling
# LSTAT    % lower status of the population
# NOX      nitric oxides concentration (parts per 10 million)

# %% [markdown]
# Помимо того, что *важность* признаков сама по себе может быть полезной информацией для конечного пользователя, на основе неё можно производить автоматический отбор признаков.
#
# Однако следует быть осторожным с использованием такого механизма. Жадная природа алгоритма построения дерева решений может привести к неадекатным значениям такой *важности* признаков. Более надёжных методом (но тоже не идеальным!), подходящим для любых моделей, а не только для лесов, является, например, *permutation importance*.
#
# На практике помимо базового Random Forest также применяют модификации:
# * Extra Random Trees - деревья строятся не по алгоритму CART, вместо этого каждое правило деления (split point) выбирается случайным образом, после чего выбирается наиболее релевантный признак. Получается быстрое время построения, но не минимальная ошибка;
# * Rotation Random Forest - перед построением каждого дерева к набору предназначенных ему признаков применяется PCA (что означает поворот осей). Такой метод полезно использовать при больших размерностях пространства признаков.
#
# #### 2. [Градиентный бустинг](https://en.wikipedia.org/wiki/Gradient_boosting)
#
# Градиентный бустинг тоже является ансамблевым методом и имеет следующие особенности:
# * деревья строятся последовательно - каждая следующая модель старается улучшить ошибку предыдущей, аппроксимируя антиградиент <u>функции потерь</u>;
# * результат работы считается как взвешенная сумма результатов базовых моделей, веса которой определяются линейным поиском на этапе построения ансамбля;
# * в случае классификации, в сравнении со случайными лесами, градиентный бустинг не позволяет хранить в листьях деревьев классы напрямую. Вместо этого алгоритм находит вероятности классов, как в логистической регрессии. Попробуйте ответить почему это так?
#
# Модели, опирающиеся на градиентный бустинг часто дают наиболее высокое качество, в сравнении со случайными лесами, линейной регрессией, SVM и т.д.
# Однако используя градиентный бустинг гораздо легче прийти к переобучению.
#
# Одним из способов борьбы с переобучением является введение скорости обучения `learning rate` - константного множителя для каждой новой базовой модели.
#
# Посмотрим как градиентный бустинг справляется с задачей регрессии на том же датасете:

# %%
from sklearn.ensemble import GradientBoostingRegressor

boston_gbm = GradientBoostingRegressor(loss='ls',
                                       learning_rate=0.1,
                                       n_estimators=100,
                                       subsample=.5,  # стохастический бустинг - деревья строятся по случайным подвыборкам
                                       criterion='friedman_mse',
                                       max_depth=3,
                                       max_features='auto',
                                       random_state=12345)
boston_gbm.fit(X_train, y_train)

cv_score = model_score(X_train, y_train, estimator=boston_gbm, cv=10, scoring='r2')
train_score = boston_gbm.score(X_train, y_train)
test_score = boston_gbm.score(X_test, y_test)

print("Score (R^2) on train:")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Score (R^2) on train:
# Cross-validation on train score: 0.8933730703147033
# Train score: 0.9785371637854611
# Test score: 0.8662862211468613

# %% [markdown]
# На практике градиентный бустинг из библиотеки sklearn обычно не применяют. Вместо него используют одну из трёх(+) библиотек, в каждой из которых реализованы свои усовершенствования оригинального алгоритма:
# * [XGBoost](https://xgboost.readthedocs.io/en/latest/) - первая библиотека, реализующая градиентный бустинг на GPU (2014 год);
# * [LightGBM](https://lightgbm.readthedocs.io/en/latest/) - библиотека от Microsoft Research (2017 год), в которой реализована обработка категориальных признаков и усовершенствования производительности;
# * **[CatBoost](https://catboost.ai/)** - библиотека от Yandex (2017 год), в которой реализована продвинутая обработка категориальных признаков и методы борьбы с переобучением. Чаще всего в задачах с категориальными признаками CatBoost работает лучше других алгоритмов даже без подстройки параметров, однако чтобы ощутить преимущество следует не применять препроцессинг для категориальных признаков. По словам команды разработчиков, использованный метод построения симметричных деревьев (Oblivious Trees) даёт прирост в качестве во всех случаях. Хотя определяющий фактор для применения таких деревьев – эффективность реализации на GPU.
#
# Установим CatBoost и проверим смелое утверждение разработчиков, не меняя ни одного параметра:

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\lfyz2\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: scipy in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from catboost) (1.8.0)
# Requirement already satisfied: plotly in c:\users\lfyz2\anaconda3\lib\site-packages (from catboost) (5.6.0)
# Requirement already satisfied: graphviz in c:\users\lfyz2\anaconda3\lib\site-packages (from catboost) (0.19.1)
# Requirement already satisfied: matplotlib in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from catboost) (3.5.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from catboost) (1.3.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from catboost) (1.22.2)
# Requirement already satisfied: six in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lfyz2\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2021.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (4.29.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (9.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score

boston_catboost = CatBoostRegressor(verbose=False,
                                    allow_writing_files=False,  # не пишем логи, о них ниже
                                    task_type='CPU')  # или 'GPU'
boston_catboost.fit(X_train, y_train, eval_set=(X_test, y_test))

cv_score = model_score(X_train, y_train, estimator=boston_catboost, cv=10, scoring='r2')
train_score = r2_score(y_train, boston_catboost.predict(X_train))
test_score = r2_score(y_test, boston_catboost.predict(X_test))

print("Score (R^2) on train:")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# Score (R^2) on train:
# Cross-validation on train score: 0.8912408888189314
# Train score: 0.9863055615503641
# Test score: 0.8551807687648003

# %% [markdown]
# #### Визуализация
#
# При обучении моделей градиентного бустинга или сетей очень полезно строить графики функции потерь для тренировочной и тестовой выборок.
#
# *CatBoost* сохраняет логи обучения по умолчанию (если `allow_writing_files == True`) в формат, совместимый с *TensorBoard* и *CatBoost Viewer*. Использовать *TensorBoard* для просмотра логов крайне удобно: достаточно установить *TensorBoard* (`pip install tensorboard`) и запустить его командой `tensorboard --logdir=catboost_info`. Сохранять результаты запусков алгоритма с различными параметрами можно с помощью записи логов в подкаталоги с уникальными именами. С установкой *CatBoostViewer* могут возникнуть небольшие сложности, поскольку он реализован с использованием *NodeJS*.

# %% [markdown]
# ### Нейронные сети
#
# Если вы планируете использовать нейронные сети, имеет смысл ознакомиться с [этим](https://github.com/abidlabs/AtomsOfDeepLearning/blob/master/Atomic%20Experiments%20in%20Deep%20Learning.ipynb) ноутбуком.
#
# С нейронными сетями чаще всего гораздо сложнее работать, чем с градиентным бустингом: приходится подбирать архитектуру, настраивать огромное число гиперпараметров; нет возможности узнать по какому принципу сеть находит ответ. Однако есть ситуации, в которых нейронные сети просто не имеют адекватно работающих альтернатив:
# * обработка изображений, видео - Convolutional NN;
# * построение эмбеддинга с учителем и без учителя - AutoEncoder, Siamese NN;
# * работа с последовательностями, в том числе генерирование - Recurrent NN и **Transformer**;
# * создание генеративных моделей без учителя - Generative Adversarial Networks, Noise Conditional Score Network, и т.д.
#
# Большая часть преимуществ достигается из-за возможности точно управлять целью обучения с помощью функции потерь, а также возможности использовать части обученной сети для решения новой задачи. Например, научив сеть предсказывать корректность словосочетания, можно применять найденный сетью способ кодирования слов для нахождения семантической близости.
#
# #### Кратко о фреймворках
#
# Есть несколько актуальных на данный момент фреймворков для работы с нейронными сетями:
# * TensorFlow - построение статических графов вычислений, автоматический вывод градиентов, блоки для построения сетей. Имеет высокий "порог вхождения". С версии `2.0` поддерживает т.н. eager-вычисления, т.е. динамические графы. Обратная совместимость с версиями `1.*` частично отсутствует и может потреобвать переписывания части кода;
# * PyTorch - построение динамических графов вычислений, лёгкий перенос вычислений на GPU (требует изменения кода);
# * Keras - построение нейронных сетей из блоков. Вычисления производятся с помощью одного из низкоуровневых фреймворков (backend): TensorFlow, CNTK, Theano и др.
#
# Если не требуется реализовывать принципиально новый алгоритм машинного обучения, внедрять наиболее современные механизмы и т.д., проще всего использовать Keras.
#
# Для некоторых архитектур нейронных сетей пишут профильные оптимизированные решения (например, для [YOLO](https://pjreddie.com/darknet/yolo/) - алгоритма быстрого поиска объектов на изображениях реализована низкоуровневая поддержка в библиотеке [Darknet](https://github.com/pjreddie/darknet)). Фреймворки вроде TensorFlow, хоть и обеспечивающие работу с несколькими GPU в кластерах, часто проигрывают по производительности узкопрофильным решениям. На практике, если применяют TensorFlow, как правило используют [оптимизаторы](https://developer.nvidia.com/tensorrt) для ускорения инференса, а для этапа тренировки тратят приличное число ресурсов.
#
#
# #### Пример
#
# Установим Keras и backend к нему:
#
# **Если у Вас есть GPU с поддержкой CUDA, имеет смысл установить Tensorflow-GPU через conda:
# `conda install tensorflow-gpu`** (в таком случае не придётся вручную устанавливать CUDA SDK)

# %%
# !pip install tensorflow
! conda install tensorflow-gpu -y
# !pip install keras
# Out:
# Requirement already satisfied: tensorflow in c:\users\lfyz2\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: setuptools in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: gast>=0.2.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from tensorflow) (1.22.2)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lfyz2\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lfyz2\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lfyz2\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# ^C
# Requirement already satisfied: keras in c:\users\lfyz2\anaconda3\lib\site-packages (2.8.0)

# %% [markdown]
# Построим сеть для решения задачи регрессии, рассмотренной выше.
#
# В Keras удобно строить сеть как последовательность слоёв, для этого используется *Sequential*-модель:

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation


def make_dense_model():
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1]))
    model.add(Activation('relu'))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dense(1))
    # чтобы модель можно было тренировать, необходимо её скомпилировать
    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse')
    
    return model


dense_model = make_dense_model()

# %% [markdown]
# Попробуем натренировать модель примерно до того же качества, что и градиентный бустинг:

# %%
from tensorflow.random import set_seed as set_random_seed
np.random.seed(1)
set_random_seed(1)

n_epochs = 1000

history = dense_model.fit(X_train, y_train,
                          epochs=n_epochs,
                          # число примеров, на которых считается градиент:
                          batch_size=16,
                          validation_data=(X_test, y_test),
                          verbose=False)

plt.plot(range(n_epochs), (history.history['loss']), c='b')
plt.plot(range(n_epochs), (history.history['val_loss']), c='g')
plt.legend(['Train Loss', 'Validation loss'])
plt.show()

# %% [markdown]
# Рассмотрим параметры обучения:
# * `epochs` - число эпох. Эпоха заканчивается, когда сеть увидела все примеры тренировочного множества;
# * `batch_size` - размер мини-батча. В [SGD](http://www.machinelearning.ru/wiki/index.php?title=Стохастический_градиентный_спуск) элементы обучающей выборки разбиваются на группы (мини-батчи) и функция потерь, вместе с её производной, рассчитывается на мини-батчах. Веса обновляются после просмотра каждого мини-батча. Вычислительно выгодней, чтобы мини-батч был достаточно большого размера, поскольку в таком случае данные будут обрабатываться параллельно;
# * `validation_data` - данные для построения кривой ошибки на валидационных данных "Validation loss".
#
# По графику функции потерь (loss) можно судить о том, имеет ли смысл обучать сеть большее число итераций.
#
# Посмотрим на качество полученной сети:

# %%
train_score = r2_score(y_train, dense_model.predict(X_train))
test_score  = r2_score(y_test, dense_model.predict(X_test))

print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Train score: 0.9879391297519634
# Test score: 0.7079773451084026

# %% [markdown]
# Получить те же результаты можно за меньшее число эпох обучения с помощью стандартизации входных данных.
# Так происходит из-за того, что в противном случае сети приходится самой сначала "искать положение данных".
#
# Сделаем предобработку с помощью `StandardScaler` для векторов признаков и `MinMaxScaler` для целевого.
# А после каждого полносвязного (`Dense`) слоя поставим `BatchNormalization` - этот механизм стандартизации внутри сети рекомендуется применять почти во всех случаях. Грубо говоря, без него каждый слой сам должен "искать положение" своих входных данных, хотя эту операцию можно сделать явно.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.layers import BatchNormalization
np.random.seed(1)
set_random_seed(1)

scaler = StandardScaler()
target_scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
y_train_scaled = target_scaler.fit_transform(y_train.reshape(y_train.shape[0], 1))
X_test_scaled = scaler.transform(X_test)
y_test_scaled = target_scaler.transform(y_test.reshape(y_test.shape[0], 1))


def make_dense_scaled_model():
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1]))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(128))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model
    
    
dense_scaled_model = make_dense_scaled_model()

history = dense_scaled_model.fit(X_train_scaled, y_train_scaled,
                                 epochs=n_epochs,
                                 batch_size=16,
                                 validation_data=(X_test_scaled, y_test_scaled),
                                 verbose=False)

plt.plot(range(len(history.history['loss'])), history.history['loss'], c='b')
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], c='g')
plt.legend(['Train Loss', 'Validation loss'])
plt.show()

# %%
def scaled_predict(model, X, target_scaler=target_scaler):
    return target_scaler.inverse_transform(model.predict(X))


train_score = r2_score(y_train, scaled_predict(dense_scaled_model, X_train_scaled))
test_score  = r2_score(y_test, scaled_predict(dense_scaled_model, X_test_scaled))

print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Train score: 0.9887448734967954
# Test score: 0.8323190441172638

# %% [markdown]
# ---
# ### Нейронные сети для обработки изображений

# %% [markdown]
# Загрузим датасет fashion mnist, содержащий изображения одежды (grayscale 28x28) 10 различных классов:

# %%
from keras.datasets import fashion_mnist
from keras.utils.np_utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
classes = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images  = test_images / 255.0
train_vectors = to_categorical(train_labels)
test_vectors = to_categorical(test_labels)

# %% [markdown]
# Установим keras-tuner для автоматического подбора гиперпараметров

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\lfyz2\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: scipy in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from keras-tuner) (1.8.0)
# Requirement already satisfied: numpy in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from keras-tuner) (1.22.2)
# Requirement already satisfied: packaging in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: tensorboard in c:\users\lfyz2\anaconda3\lib\site-packages (from keras-tuner) (2.8.0)
# Requirement already satisfied: ipython in c:\users\lfyz2\anaconda3\lib\site-packages (from keras-tuner) (7.29.0)
# Requirement already satisfied: kt-legacy in c:\users\lfyz2\anaconda3\lib\site-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: requests in c:\users\lfyz2\anaconda3\lib\site-packages (from keras-tuner) (2.26.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (58.0.4)
# Requirement already satisfied: pygments in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (2.10.0)
# Requirement already satisfied: matplotlib-inline in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: decorator in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.0)
# Requirement already satisfied: backcall in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: colorama in c:\users\lfyz2\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\lfyz2\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from packaging->keras-tuner) (3.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests->keras-tuner) (3.2)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (3.19.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.44.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (2.6.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lfyz2\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.0.0)
# Requirement already satisfied: six in c:\users\lfyz2\appdata\roaming\python\python39\site-packages (from absl-py>=0.4->tensorboard->keras-tuner) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lfyz2\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lfyz2\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lfyz2\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lfyz2\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.0)

# %% [markdown]
# Для того, чтобы с помощью `keras-tuner` использовать автоматический подбор гиперпараметров, надо определить функцию, принимающую на вход специальный объект `hp` и возвращающую построенную модель.
#
# У объекта `hp` можно вызывать методы `Choice`, `Int`, `Boolean` и другие для указания, из каких значений перебирать гиперпараметры в данном месте.
#
# Ниже приведён пример кода, где определяется функция `build_model`, которая будет передана "тюнеру" для поиска лучших гиперпараметров.

# %%
from keras import Model, Input
from keras.layers import (Conv2D, MaxPooling2D, Flatten, Reshape, GlobalMaxPooling2D,
                          Activation)
import keras_tuner as kt

np.random.seed(1)
set_random_seed(1)

def build_model(hp):
    image_model = Sequential()
    image_model.add(Reshape((28, 28, 1), input_shape=(28, 28)))
    image_model.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1), activation='relu'))
    image_model.add(BatchNormalization())
    image_model.add(MaxPooling2D())
    
    # В следующем слое сообщаем keras tuner гиперпараметры, из которых надо искать лучшие
    image_model.add(Conv2D(hp.Int(  # С помощью hp.Int перебираем целые числа в качестве гиперпараметров
                                'second_conv2d_out_channels',  # название нашего гиперпараметра, для которого ищем значение
                                min_value=4,
                                max_value=5,
                                step=1,
                            ),
                           kernel_size=(3, 3), strides=(1, 1),
                           activation=hp.Choice(  # Перебираем значения в качестве гиперпараметров
                               'second_conv2d_activation',  # название нашего гиперпараметра, для которого ищем значение
                               ['relu', 'tanh'],  # список, из которого можно выбирать значения гиперпараметра
                           )))
    
    # Следующий гиперпараметр - "наличие слоя батч-нормализации"
    if hp.Boolean("need_batch_norm_after_second_conv2d"):
        # Сюда зайдём в случае, когда keras-tuner подставит True в качестве гиперпараметра need_batch_norm_after_second_conv2d
        # И тогда в модель будет добавлен слой батч-нормализации
        image_model.add(BatchNormalization())
    
    image_model.add(MaxPooling2D())
    image_model.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1), activation='relu'))
    image_model.add(BatchNormalization())
    image_model.add(Flatten())

    image_model.add(Dense(4, activation='relu'))
    image_model.add(Dense(10, activation='softmax'))
    image_model.compile(optimizer='adam',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])
    # Функция должна возвращать построенную и скомпилированную модель
    return image_model

# %% [markdown]
# Далее создадим тюнер, который будет искать лучшие гиперпараметры из заданных с помощью случайного поиска (random search).
#
# Случайный поиск используется, когда возможных конфигураций модели слишком много, так как процесс обучения одной модели может быть затратным. При случайном поиске гиперпараметры будут выбираться из возможных случайным образом. Нам нужно лишь указать максимальное количество различных моделей, которые следует обучать.
#
# Лучшими гиперпараметрами тюнер считает модель, которая после обучения показала лучшее качество по метрике, переданной аргументом `objective`.

# %%
# Создаём тюнер
tuner = kt.RandomSearch(
    build_model,  # Передаём функцию, определённую выше
    objective='val_loss',  # Передаём критерий качества лучшей модели
    max_trials=3,  # Максимальное кол-во возможных конфигураций, которые тюнер "проверит"
    seed=1234,
)

# Запускаем процесс поиска
# В качестве аргументов передаём всё то, что передали бы в метод fit, если бы подбора гиперпараметров не было
tuner.search(train_images, train_vectors, epochs=5, batch_size=128, validation_data=(test_images, test_vectors))
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\untitled_project\oracle.json
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# Посмотрим итоги поиска

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in .\untitled_project
# Showing 10 best trials
# Objective(name='val_loss', direction='min')
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 5
# second_conv2d_activation: tanh
# need_batch_norm_after_second_conv2d: True
# Score: 0.6039419770240784
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 4
# second_conv2d_activation: relu
# need_batch_norm_after_second_conv2d: True
# Score: 0.621146559715271
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 5
# second_conv2d_activation: tanh
# need_batch_norm_after_second_conv2d: False
# Score: 0.6227321028709412

# %% [markdown]
# Создадим модель, которую тюнер признал лучшей

# %%
best_model = tuner.get_best_models()[0]  # Создадим модель
best_model.build(input_shape=(None, 28, 28))  # Построим модель с лучшими гиперпараметрами
best_model.summary()  # Посмотрим на архитектуру построенной модели, она соответствует выбранным гиперпараметрам
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 26, 26, 4)         40
#
#  batch_normalization (BatchN  (None, 26, 26, 4)        16
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 4)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 5)         185
#
#  batch_normalization_1 (Batc  (None, 11, 11, 5)        20
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 5)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 4)           184
#
#  batch_normalization_2 (Batc  (None, 3, 3, 4)          16
#  hNormalization)
#
#  flatten (Flatten)           (None, 36)                0
#
#  dense (Dense)               (None, 4)                 148
#
#  dense_1 (Dense)             (None, 10)                50
#
# =================================================================
# Total params: 659
# Trainable params: 633
# Non-trainable params: 26
# _________________________________________________________________

# %% [markdown]
# Замерим `accuracy` для найденной модели на тестовых данных

# %%
from sklearn.metrics import accuracy_score

print(f"Качество найденной модели: {accuracy_score(test_labels, np.argmax(best_model.predict(test_images), axis=-1))}")
# Out:
# Качество найденной модели: 0.7791

# %% [markdown]
# #### Задание 2.
#
# Измените параметры свёрточной сети / параметры обучения (метода `fit`), чтобы повысить качество (accuracy) на тестовых данных до **0.88**.
#
# При желании можно использовать автоматический подбор гиперпараметров с помощью keras-tuner, но можно обойтись и без него.

# %%
np.random.seed(1)
set_random_seed(1)

classification_model = Sequential()
classification_model.add(Reshape((28, 28, 1), input_shape=(28, 28)))
# далее input_shape указывать не обязательно
# следует изменить параметры следующих слоёв:
classification_model.add(Conv2D(16, kernel_size=(2, 2), strides=(1, 1),
                       input_shape=(28, 28, 1), activation='relu'))
classification_model.add(BatchNormalization())
classification_model.add(MaxPooling2D())
classification_model.add(Conv2D(16, kernel_size=(2, 2), strides=(1, 1),
                       input_shape=(14, 14, 4), activation='relu'))
classification_model.add(BatchNormalization())
classification_model.add(MaxPooling2D())
classification_model.add(Conv2D(16, kernel_size=(2, 2), strides=(1, 1),
                       input_shape=(7, 7, 4), activation='relu'))

# Слой ниже (и последующие слои) менять не надо
classification_model.add(Flatten(name='flatten'))
classification_model.add(Dense(4, activation='relu'))
classification_model.add(Dense(10, activation='softmax'))

# %%
classification_model.compile(optimizer='adam', 
                             loss='categorical_crossentropy',
                             metrics=['accuracy'])

classification_model.fit(train_images, train_vectors, epochs=7, batch_size=128,
                         validation_data=(test_images, test_vectors))
# Out:
# Epoch 1/7
# 469/469 [==============================] - 5s 9ms/step - loss: 0.3864 - accuracy: 0.8758 - val_loss: 0.4120 - val_accuracy: 0.8626
# Epoch 2/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3593 - accuracy: 0.8807 - val_loss: 0.3905 - val_accuracy: 0.8689
# Epoch 3/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3416 - accuracy: 0.8842 - val_loss: 0.3888 - val_accuracy: 0.8681
# Epoch 4/7
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3290 - accuracy: 0.8861 - val_loss: 0.3790 - val_accuracy: 0.8699
# Epoch 5/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3212 - accuracy: 0.8883 - val_loss: 0.3770 - val_accuracy: 0.8691
# Epoch 6/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3110 - accuracy: 0.8915 - val_loss: 0.3537 - val_accuracy: 0.8756
# Epoch 7/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3055 - accuracy: 0.8935 - val_loss: 0.3426 - val_accuracy: 0.8811

# %%
def evaluate_model_for_task_2(model):
    test_acc = accuracy_score(test_labels, np.argmax(model.predict(test_images), axis=-1))
    print(f"Качество: {test_acc}")
    print("Тест на качество {}".format("не пройден :(" if 0.88 > test_acc else "пройден :)"))

# %% [markdown]
# Вызовите функцию `evaluate_model_for_task_2`, передав ей обученную модель, чтобы увидеть качество этой модели. При сдаче задания качество должно быть не ниже **0.88**
#
# _Примечание: модель, полученная в ходе выполнения этого задания, будет использована далее, поэтому важно, чтобы она называлась_ `classification_model`

# %%
#  classification_model = best_model
evaluate_model_for_task_2(classification_model)
# Out:
# Качество: 0.8811
# Тест на качество пройден :)

# %% [markdown]
# ---
#
# Посмотрим как выглядит предсказание:

# %%
np.random.seed(123456)
test_ind = np.random.randint(test_images.shape[0])
test_image = test_images[test_ind]
test_vector = test_vectors[test_ind]
predicted_test_vector = classification_model.predict(test_image[np.newaxis]).reshape((10,))

plt.imshow(test_image, cmap='gray')
plt.title('Тестовое изображение')
plt.figure()

fig, ax = plt.subplots(1, 2, figsize=(17, 4))
ax[0].bar(range(10), test_vector, tick_label=classes)
ax[1].bar(range(10), predicted_test_vector, tick_label=classes)
for i, title in enumerate(['Правильный вектор классов', 'Предсказанный вектор']): ax[i].set_title(title)

# %% [markdown]
# Получим предсказания для первых 100 изображений:

# %%
# %time
predicted_vectors = classification_model.predict(test_images[:100]).reshape((100, 10))
# Out:
# Wall time: 0 ns

# %% [markdown]
# Посмотрим на каких изображениях сеть ошибается:

# %%
from sklearn.metrics import confusion_matrix

predicted_labels = np.argmax(predicted_vectors, axis=1)  # предсказанные индексы классов - где верояность наибольшая

pred = test_labels[:100] != predicted_labels
misclassified_images = test_images[:100][pred]
misclassified_correct = test_labels[:100][pred]
misclassified_predicted = predicted_labels[:100][pred]

cm = confusion_matrix(test_labels[:100], predicted_labels[:100])
plt.imshow(cm, interpolation='nearest')
plt.xticks(range(10), classes, rotation=90)
plt.yticks(range(10), classes)
plt.colorbar()
plt.title("Confusion matrix")
plt.figure()

fig, ax = plt.subplots(2, 6, figsize=(15, 4))
for i in range(2 * 6):
    ax.flatten()[i].imshow(misclassified_images[i], cmap='gray')
    ax.flatten()[i].axis('off')
    ax.flatten()[i].set_title(f"{classes[misclassified_predicted[i]]} / {classes[misclassified_correct[i]]}")

# %% [markdown]
# ---
#
# ### Gradient Boosting для классификации изображений
#
#
#
# Будем рассматривать ту же задачу, что и в прошлом задании.
#
# _Примечание: результатом задания 2 является модель-классификатор_ `classification_model`.
#
# Возьмём лишь часть модели `classification_model` (до полносвязных слоёв), чтобы получить векторы признаков.

# %%
# Из слоёв classification_model составим модель для извлечения вектора признаков
feature_extractor = Model(
    inputs=classification_model.inputs,
    outputs=classification_model.get_layer(name="flatten").output,  # Указываем слой, выходы после которого нас интересуют
)

# %% [markdown]
# Получим векторы признаков:

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
#tf.device('/device:GPU:0')
train_encoded = feature_extractor(train_images)
test_encoded = feature_extractor(test_images)
print(f'train_encoded.shape = {train_encoded.shape}')
print(f'test_encoded.shape = {test_encoded.shape}')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7485909997683199912
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2256220980
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4500782664601921349
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11272/3474093902.py in <module>
#       2 print(device_lib.list_local_devices())
#       3 #tf.device('/device:GPU:0')
# ----> 4 train_encoded = feature_extractor(train_images)
#       5 test_encoded = feature_extractor(test_images)
#       6 print(f'train_encoded.shape = {train_encoded.shape}')
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7187
#    7188
#
# ResourceExhaustedError: Exception encountered when calling layer "conv2d_3" (type Conv2D).
#
# OOM when allocating tensor with shape[60000,27,27,16] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv2D]
#
# Call arguments received:
#   • inputs=tf.Tensor(shape=(60000, 28, 28, 1), dtype=float32)

# %% [markdown]
# ---
#
# #### Задание 3.
#
# Для векторов признаков, полученных из предыдущего задания, достроим классификатор на основе градиентного бустинга.
#
# **Требуется:**
#
# Изменить параметры `CatBoostClassifier` ниже, чтобы повысить качество (accuracy), желательно до `0.89`:

# %%
dim_reduction = PCA(n_components=train_encoded.shape[-1]) # понизим размерность, используя информацию о классах
small_train_encoded = dim_reduction.fit_transform(train_encoded)
small_test_encoded = dim_reduction.transform(test_encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11272/2711576164.py in <module>
# ----> 1 dim_reduction = PCA(n_components=train_encoded.shape[-1]) # понизим размерность, используя информацию о классах
#       2 small_train_encoded = dim_reduction.fit_transform(train_encoded)
#       3 small_test_encoded = dim_reduction.transform(test_encoded)
#
# NameError: name 'train_encoded' is not defined

# %%
from catboost import CatBoostClassifier

image_gbm = CatBoostClassifier(loss_function='MultiClass',
                               # эти параметры следует подобрать:
                               depth=5,
                               learning_rate=0.033,
                               iterations=500)
image_gbm.fit(small_train_encoded, train_labels, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11272/2457944771.py in <module>
#       6                                learning_rate=0.033,
#       7                                iterations=500)
# ----> 8 image_gbm.fit(small_train_encoded, train_labels, verbose=0)
#
# NameError: name 'small_train_encoded' is not defined

# %%
image_gbm_labels = image_gbm.predict(small_test_encoded)
image_gbm_score = accuracy_score(test_labels, image_gbm_labels)
print(f"Качество: {image_gbm_score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11272/3034876851.py in <module>
# ----> 1 image_gbm_labels = image_gbm.predict(small_test_encoded)
#       2 image_gbm_score = accuracy_score(test_labels, image_gbm_labels)
#       3 print(f"Качество: {image_gbm_score}")
#
# NameError: name 'small_test_encoded' is not defined

# %% [markdown]
# ---
#
# ## Аугментация
#
# Часто доступные на этапе обучения размеченные данные оказываются смещёнными, не целиком покрывающими допустимое для данной задачи распределение входных данных.
# Также, при использовании нейронных сетей с большим числом параметров, на этапе обучения необходимо большое число различных данных, чтобы модель не деградировала до "табличной функции", запоминая все входные данные.
#
# Для борьбы с обеими проблемами хорошо подходит подход искусственного расширения обучающего набора данных – аугментация. Идея заключается в применении случайных трансформаций к каждому отдельному изображению, при сохранении меток классов. Таким образом можно получить датасет произвольного размера и добиться от нейронной сети определённых свойств (разумеется, для фиксированного, ограниченного распределения входных данных), например: инвариантности к повороту объекта – за счёт обучения на всевозможных поворотах входных изображений.
#
# Важно, что выбор набора трансформаций и распределений из которых генерируются их параметры, специфичен для каждой задачи. Например, при классификации деревьев не разумно выполнять повороты на $\pi$, поскольку известно, что деревья всегда растут снизу вверх.
#
# ---
#
# Будем загружать датасет из GoogleDisk, установим библиотеку для удобного скачивания:

# %%
# !pip install googledrivedownloader
# Out:
# Collecting googledrivedownloader
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Installing collected packages: googledrivedownloader
# Successfully installed googledrivedownloader-0.4

# %% [markdown]
# Скачаем файлы с данными:

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
import os

ids_to_file_names = {
    '1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv': 'fashion_images.npy',
    '15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI': 'fashion_labels.npy',
    '1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o': 'val_fashion_images.npy',
    '1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y': 'val_fashion_labels.npy',
    '1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4': 'test_fashion_images.npy',
}

for file_id in ids_to_file_names:
    # Качаем файл только если он ещё не скачан
    if not os.path.isfile(ids_to_file_names[file_id]):
        gdd.download_file_from_google_drive(file_id=file_id,
                                            dest_path=os.path.join('.', ids_to_file_names[file_id]),
                                            unzip=True)
# Out:
# Downloading 1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv into .\fashion_images.npy... Done.
# Unzipping...Downloading 15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI into .\fashion_labels.npy...
# C:\Users\lfyz2\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o into .\val_fashion_images.npy...
# C:\Users\lfyz2\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y into .\val_fashion_labels.npy...
# C:\Users\lfyz2\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4 into .\test_fashion_images.npy...
# C:\Users\lfyz2\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...
# C:\Users\lfyz2\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))

# %% [markdown]
# Загрузим данные – изображения 64x64 с цветным шумом и случайно аффинно трансформированными снимками одежды:

# %%
fashion_images = np.load("fashion_images.npy")
fashion_labels = np.load("fashion_labels.npy")

val_fashion_images = np.load("val_fashion_images.npy")
val_fashion_labels = np.load("val_fashion_labels.npy")

test_fashion_images = np.load("test_fashion_images.npy")

# %% [markdown]
# В качестве тренировочного и валидационного датасета даны изображения и метки (вектора вероятностей классов одежды), в качестве тестового – только изображения.

# %% [markdown]
# Ниже дана модель, гиперпараметры которой (количества каналов, размеры ядер, функции активации, архитектуру и т.п.) менять **нельзя**.

# %%
def make_fashion_model():
    imodel = Sequential()
    imodel.add(Reshape((64, 64, 3), input_shape=(64, 64, 3)))
    imodel.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(8, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(16, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(32, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(64, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(128, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(Flatten())

    iclf = Sequential()
    iclf.add(imodel)
    iclf.add(Dense(10, activation='softmax'))

    iclf.compile(optimizer='adam', 
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    
    return iclf

# %% [markdown]
# ---
#
# #### Задание 4 (дополнительное).
#
# **Внимание!** Это задание повышенной сложности, за его решение даётся 3 балла, выполнять его необязательно.
#
# Найти такие параметры аугментации (ниже), чтобы качество классификации (accuracy) на тестовых данных было не ниже $0.6$.
#
# *Настоятельно рекомендуется сначала внимательно изучить обучающую и тестовую выборки, а не подбирать параметры случайным образом.*

# %%
train_fashion_images = fashion_images.copy()
# здесь можно сделать предварительную обработку всего обучающего датасета
train_fashion_labels = fashion_labels

# %%
from keras.preprocessing.image import ImageDataGenerator

# здесь следует изменить параметры аугментации:
aug = ImageDataGenerator(featurewise_center=False,
                   samplewise_center=False,
                   featurewise_std_normalization=False,
                   samplewise_std_normalization=False,
                   rotation_range=0.0,
                   width_shift_range=32.0,
                   height_shift_range=32.0,
                   brightness_range=None,
                   shear_range=0.0,
                   zoom_range=0.0,
                   channel_shift_range=0.0,
                   fill_mode='nearest',
                   cval=0.0,
                   horizontal_flip=True,
                   vertical_flip=False,
                   rescale=0.0)

# %% [markdown]
# Из параметров обучения можно менять `batch_size` и `epochs`, но использовать можно не больше 200 эпох.

# %%
batch_size = 128
fashion_clf = make_fashion_model()

aug.fit(train_fashion_images)
gen = aug.flow(train_fashion_images, train_fashion_labels,
               batch_size=batch_size)

hist = fashion_clf.fit(gen,
               steps_per_epoch=len(train_fashion_images) // batch_size,
               epochs=200,
               validation_data=(val_fashion_images, val_fashion_labels))
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 199ms/step - loss: 2.8145 - accuracy: 0.1193 - val_loss: 2.3050 - val_accuracy: 0.0600
# Epoch 2/200
# 7/7 [==============================] - 1s 165ms/step - loss: 2.4810 - accuracy: 0.1525 - val_loss: 2.3162 - val_accuracy: 0.0400
# Epoch 3/200
# 7/7 [==============================] - 1s 184ms/step - loss: 2.3471 - accuracy: 0.1778 - val_loss: 2.3257 - val_accuracy: 0.0400
# Epoch 4/200
# 7/7 [==============================] - 1s 212ms/step - loss: 2.2126 - accuracy: 0.2122 - val_loss: 2.3345 - val_accuracy: 0.0400
# Epoch 5/200
# 7/7 [==============================] - 1s 167ms/step - loss: 2.0825 - accuracy: 0.2374 - val_loss: 2.3472 - val_accuracy: 0.0400
# Epoch 6/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.9644 - accuracy: 0.2810 - val_loss: 2.3351 - val_accuracy: 0.0400
# Epoch 7/200
# 7/7 [==============================] - 1s 180ms/step - loss: 1.9624 - accuracy: 0.2615 - val_loss: 2.3377 - val_accuracy: 0.0400
# Epoch 8/200
# 7/7 [==============================] - 1s 183ms/step - loss: 1.9121 - accuracy: 0.2947 - val_loss: 2.3518 - val_accuracy: 0.0400
# Epoch 9/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.8851 - accuracy: 0.2661 - val_loss: 2.3157 - val_accuracy: 0.0800
# Epoch 10/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.8625 - accuracy: 0.2936 - val_loss: 2.3170 - val_accuracy: 0.0600
# Epoch 11/200
# 7/7 [==============================] - 2s 212ms/step - loss: 1.8630 - accuracy: 0.3005 - val_loss: 2.3154 - val_accuracy: 0.0800
# Epoch 12/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.8149 - accuracy: 0.3326 - val_loss: 2.3043 - val_accuracy: 0.1200
# Epoch 13/200
# 7/7 [==============================] - 1s 191ms/step - loss: 1.7208 - accuracy: 0.3394 - val_loss: 2.3141 - val_accuracy: 0.0800
# Epoch 14/200
# 7/7 [==============================] - 2s 215ms/step - loss: 1.7141 - accuracy: 0.3417 - val_loss: 2.3108 - val_accuracy: 0.0800
# Epoch 15/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.6905 - accuracy: 0.3578 - val_loss: 2.3265 - val_accuracy: 0.0800
# Epoch 16/200
# 7/7 [==============================] - 1s 180ms/step - loss: 1.6837 - accuracy: 0.3516 - val_loss: 2.3434 - val_accuracy: 0.0800
# Epoch 17/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.6539 - accuracy: 0.3681 - val_loss: 2.3371 - val_accuracy: 0.0800
# Epoch 18/200
# 7/7 [==============================] - 1s 172ms/step - loss: 1.6122 - accuracy: 0.4117 - val_loss: 2.3396 - val_accuracy: 0.0800
# Epoch 19/200
# 7/7 [==============================] - 1s 204ms/step - loss: 1.5751 - accuracy: 0.4174 - val_loss: 2.3520 - val_accuracy: 0.0800
# Epoch 20/200
# 7/7 [==============================] - 1s 180ms/step - loss: 1.6070 - accuracy: 0.3991 - val_loss: 2.2774 - val_accuracy: 0.1800
# Epoch 21/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.5435 - accuracy: 0.4289 - val_loss: 2.2507 - val_accuracy: 0.1600
# Epoch 22/200
# 7/7 [==============================] - 1s 201ms/step - loss: 1.5399 - accuracy: 0.4209 - val_loss: 2.3065 - val_accuracy: 0.1600
# Epoch 23/200
# 7/7 [==============================] - 1s 195ms/step - loss: 1.5408 - accuracy: 0.4323 - val_loss: 2.3963 - val_accuracy: 0.1200
# Epoch 24/200
# 7/7 [==============================] - 1s 166ms/step - loss: 1.4813 - accuracy: 0.4461 - val_loss: 2.4008 - val_accuracy: 0.1600
# Epoch 25/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.5264 - accuracy: 0.4495 - val_loss: 2.3088 - val_accuracy: 0.0800
# Epoch 26/200
# 7/7 [==============================] - 1s 183ms/step - loss: 1.5082 - accuracy: 0.4392 - val_loss: 2.3230 - val_accuracy: 0.1400
# Epoch 27/200
# 7/7 [==============================] - 1s 176ms/step - loss: 1.4999 - accuracy: 0.4427 - val_loss: 2.3112 - val_accuracy: 0.1600
# Epoch 28/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.4965 - accuracy: 0.4209 - val_loss: 2.3011 - val_accuracy: 0.1400
# Epoch 29/200
# 7/7 [==============================] - 1s 201ms/step - loss: 1.4852 - accuracy: 0.4554 - val_loss: 2.3152 - val_accuracy: 0.2000
# Epoch 30/200
# 7/7 [==============================] - 1s 171ms/step - loss: 1.4243 - accuracy: 0.4702 - val_loss: 2.3647 - val_accuracy: 0.1200
# Epoch 31/200
# 7/7 [==============================] - 1s 188ms/step - loss: 1.4482 - accuracy: 0.4484 - val_loss: 2.3956 - val_accuracy: 0.1400
# Epoch 32/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.4147 - accuracy: 0.4450 - val_loss: 2.3637 - val_accuracy: 0.1800
# Epoch 33/200
# 7/7 [==============================] - 1s 210ms/step - loss: 1.3825 - accuracy: 0.4759 - val_loss: 2.2625 - val_accuracy: 0.2400
# Epoch 34/200
# 7/7 [==============================] - 1s 176ms/step - loss: 1.4204 - accuracy: 0.4782 - val_loss: 2.3009 - val_accuracy: 0.1800
# Epoch 35/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.3963 - accuracy: 0.4748 - val_loss: 2.3405 - val_accuracy: 0.1600
# Epoch 36/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.3938 - accuracy: 0.4817 - val_loss: 2.3557 - val_accuracy: 0.1800
# Epoch 37/200
# 7/7 [==============================] - 1s 187ms/step - loss: 1.3771 - accuracy: 0.4817 - val_loss: 2.3487 - val_accuracy: 0.1800
# Epoch 38/200
# 7/7 [==============================] - 1s 185ms/step - loss: 1.3171 - accuracy: 0.5161 - val_loss: 2.2223 - val_accuracy: 0.1800
# Epoch 39/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.3143 - accuracy: 0.4943 - val_loss: 2.2146 - val_accuracy: 0.1800
# Epoch 40/200
# 7/7 [==============================] - 1s 186ms/step - loss: 1.3614 - accuracy: 0.4885 - val_loss: 2.1999 - val_accuracy: 0.2200
# Epoch 41/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.3320 - accuracy: 0.4931 - val_loss: 2.2655 - val_accuracy: 0.2200
# Epoch 42/200
# 7/7 [==============================] - 1s 185ms/step - loss: 1.3372 - accuracy: 0.5011 - val_loss: 2.3163 - val_accuracy: 0.2200
# Epoch 43/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.3275 - accuracy: 0.5034 - val_loss: 2.3539 - val_accuracy: 0.2000
# Epoch 44/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.3680 - accuracy: 0.4794 - val_loss: 2.1512 - val_accuracy: 0.2800
# Epoch 45/200
# 7/7 [==============================] - 1s 202ms/step - loss: 1.3223 - accuracy: 0.4900 - val_loss: 2.2361 - val_accuracy: 0.3400
# Epoch 46/200
# 7/7 [==============================] - 1s 199ms/step - loss: 1.3167 - accuracy: 0.4920 - val_loss: 2.2250 - val_accuracy: 0.2800
# Epoch 47/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.3421 - accuracy: 0.4989 - val_loss: 2.2822 - val_accuracy: 0.2800
# Epoch 48/200
# 7/7 [==============================] - 1s 178ms/step - loss: 1.3370 - accuracy: 0.5011 - val_loss: 2.1520 - val_accuracy: 0.3800
# Epoch 49/200
# 7/7 [==============================] - 1s 184ms/step - loss: 1.2331 - accuracy: 0.5206 - val_loss: 2.1504 - val_accuracy: 0.3200
# Epoch 50/200
# 7/7 [==============================] - 1s 176ms/step - loss: 1.3022 - accuracy: 0.5069 - val_loss: 2.2689 - val_accuracy: 0.2600
# Epoch 51/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.2494 - accuracy: 0.5092 - val_loss: 2.1101 - val_accuracy: 0.3600
# Epoch 52/200
# 7/7 [==============================] - 1s 174ms/step - loss: 1.3942 - accuracy: 0.4805 - val_loss: 1.9698 - val_accuracy: 0.3200
# Epoch 53/200
# 7/7 [==============================] - 1s 185ms/step - loss: 1.2491 - accuracy: 0.5126 - val_loss: 2.0373 - val_accuracy: 0.3600
# Epoch 54/200
# 7/7 [==============================] - 1s 189ms/step - loss: 1.2793 - accuracy: 0.5356 - val_loss: 2.0038 - val_accuracy: 0.3600
# Epoch 55/200
# 7/7 [==============================] - 1s 181ms/step - loss: 1.2343 - accuracy: 0.5390 - val_loss: 2.1244 - val_accuracy: 0.2800
# Epoch 56/200
# 7/7 [==============================] - 1s 191ms/step - loss: 1.3333 - accuracy: 0.5046 - val_loss: 1.8158 - val_accuracy: 0.4200
# Epoch 57/200
# 7/7 [==============================] - 1s 185ms/step - loss: 1.2377 - accuracy: 0.5493 - val_loss: 2.0576 - val_accuracy: 0.4000
# Epoch 58/200
# 7/7 [==============================] - 1s 182ms/step - loss: 1.2444 - accuracy: 0.5436 - val_loss: 1.9833 - val_accuracy: 0.4000
# Epoch 59/200
# 7/7 [==============================] - 1s 178ms/step - loss: 1.1972 - accuracy: 0.5436 - val_loss: 1.7586 - val_accuracy: 0.4600
# Epoch 60/200
# 7/7 [==============================] - 1s 177ms/step - loss: 1.2807 - accuracy: 0.5223 - val_loss: 2.0962 - val_accuracy: 0.3000
# Epoch 61/200
# 7/7 [==============================] - 1s 192ms/step - loss: 1.2636 - accuracy: 0.5089 - val_loss: 2.3562 - val_accuracy: 0.2600
# Epoch 62/200
# 7/7 [==============================] - 1s 172ms/step - loss: 1.1909 - accuracy: 0.5516 - val_loss: 2.0911 - val_accuracy: 0.3800
# Epoch 63/200
# 7/7 [==============================] - 1s 183ms/step - loss: 1.2171 - accuracy: 0.5528 - val_loss: 1.9165 - val_accuracy: 0.4200
# Epoch 64/200
# 7/7 [==============================] - 1s 178ms/step - loss: 1.2014 - accuracy: 0.5619 - val_loss: 2.2849 - val_accuracy: 0.3000
# Epoch 65/200
# 7/7 [==============================] - 1s 191ms/step - loss: 1.2241 - accuracy: 0.5321 - val_loss: 2.1417 - val_accuracy: 0.3600
# Epoch 66/200
# 7/7 [==============================] - 1s 204ms/step - loss: 1.1999 - accuracy: 0.5378 - val_loss: 1.7443 - val_accuracy: 0.4000
# Epoch 67/200
# 7/7 [==============================] - 1s 174ms/step - loss: 1.2064 - accuracy: 0.5344 - val_loss: 1.5916 - val_accuracy: 0.4600
# Epoch 68/200
# 7/7 [==============================] - 1s 183ms/step - loss: 1.1769 - accuracy: 0.5573 - val_loss: 1.6362 - val_accuracy: 0.4000
# Epoch 69/200
# 7/7 [==============================] - 1s 189ms/step - loss: 1.1710 - accuracy: 0.5436 - val_loss: 1.6519 - val_accuracy: 0.4600
# Epoch 70/200
# 7/7 [==============================] - 1s 178ms/step - loss: 1.2128 - accuracy: 0.5539 - val_loss: 1.4558 - val_accuracy: 0.5200
# Epoch 71/200
# 7/7 [==============================] - 1s 186ms/step - loss: 1.2341 - accuracy: 0.5092 - val_loss: 1.4751 - val_accuracy: 0.4800
# Epoch 72/200
# 7/7 [==============================] - 1s 174ms/step - loss: 1.2109 - accuracy: 0.5298 - val_loss: 1.5600 - val_accuracy: 0.4600
# Epoch 73/200
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2136 - accuracy: 0.5642 - val_loss: 1.6145 - val_accuracy: 0.5400
# Epoch 74/200
# 7/7 [==============================] - 1s 190ms/step - loss: 1.2270 - accuracy: 0.5528 - val_loss: 1.9574 - val_accuracy: 0.4000
# Epoch 75/200
# 7/7 [==============================] - 1s 179ms/step - loss: 1.1811 - accuracy: 0.5516 - val_loss: 1.9340 - val_accuracy: 0.4200
# Epoch 76/200
# 7/7 [==============================] - 2s 220ms/step - loss: 1.1824 - accuracy: 0.5714 - val_loss: 1.6552 - val_accuracy: 0.5200
# Epoch 77/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.1799 - accuracy: 0.5470 - val_loss: 1.6070 - val_accuracy: 0.5000
# Epoch 78/200
# 7/7 [==============================] - 2s 214ms/step - loss: 1.2033 - accuracy: 0.5550 - val_loss: 1.6889 - val_accuracy: 0.4600
# Epoch 79/200
# 7/7 [==============================] - 2s 231ms/step - loss: 1.1695 - accuracy: 0.5636 - val_loss: 1.7018 - val_accuracy: 0.4600
# Epoch 80/200
# 7/7 [==============================] - 1s 189ms/step - loss: 1.1844 - accuracy: 0.5688 - val_loss: 1.6103 - val_accuracy: 0.4400
# Epoch 81/200
# 7/7 [==============================] - 1s 206ms/step - loss: 1.1673 - accuracy: 0.5619 - val_loss: 1.4129 - val_accuracy: 0.5400
# Epoch 82/200
# 7/7 [==============================] - 1s 180ms/step - loss: 1.1906 - accuracy: 0.5608 - val_loss: 1.3169 - val_accuracy: 0.5800
# Epoch 83/200
# 7/7 [==============================] - 1s 203ms/step - loss: 1.1391 - accuracy: 0.5636 - val_loss: 1.5342 - val_accuracy: 0.4200
# Epoch 84/200
# 7/7 [==============================] - 1s 184ms/step - loss: 1.1734 - accuracy: 0.5493 - val_loss: 1.3675 - val_accuracy: 0.5200
# Epoch 85/200
# 7/7 [==============================] - 1s 185ms/step - loss: 1.2036 - accuracy: 0.5505 - val_loss: 1.7553 - val_accuracy: 0.4400
# Epoch 86/200
# 7/7 [==============================] - 1s 206ms/step - loss: 1.1416 - accuracy: 0.5692 - val_loss: 1.4270 - val_accuracy: 0.4600
# Epoch 87/200
# 7/7 [==============================] - 2s 235ms/step - loss: 1.1826 - accuracy: 0.5516 - val_loss: 1.3489 - val_accuracy: 0.5400
# Epoch 88/200
# 7/7 [==============================] - 1s 200ms/step - loss: 1.1644 - accuracy: 0.5310 - val_loss: 1.3051 - val_accuracy: 0.5000
# Epoch 89/200
# 7/7 [==============================] - 2s 269ms/step - loss: 1.1059 - accuracy: 0.5917 - val_loss: 1.2601 - val_accuracy: 0.5600
# Epoch 90/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.1557 - accuracy: 0.5619 - val_loss: 1.2502 - val_accuracy: 0.5200
# Epoch 91/200
# 7/7 [==============================] - 2s 218ms/step - loss: 1.1501 - accuracy: 0.5665 - val_loss: 1.3453 - val_accuracy: 0.5600
# Epoch 92/200
# 7/7 [==============================] - 2s 278ms/step - loss: 1.1398 - accuracy: 0.5654 - val_loss: 1.1992 - val_accuracy: 0.5400
# Epoch 93/200
# 7/7 [==============================] - 2s 223ms/step - loss: 1.1303 - accuracy: 0.5700 - val_loss: 1.2145 - val_accuracy: 0.5800
# Epoch 94/200
# 7/7 [==============================] - 1s 202ms/step - loss: 1.1497 - accuracy: 0.5636 - val_loss: 1.1619 - val_accuracy: 0.6200
# Epoch 95/200
# 7/7 [==============================] - 2s 231ms/step - loss: 1.1069 - accuracy: 0.5665 - val_loss: 1.3105 - val_accuracy: 0.5200
# Epoch 96/200
# 7/7 [==============================] - 2s 214ms/step - loss: 1.1339 - accuracy: 0.5539 - val_loss: 1.5053 - val_accuracy: 0.5400
# Epoch 97/200
# 7/7 [==============================] - 1s 200ms/step - loss: 1.0933 - accuracy: 0.5872 - val_loss: 1.5194 - val_accuracy: 0.5600
# Epoch 98/200
# 7/7 [==============================] - 1s 207ms/step - loss: 1.1189 - accuracy: 0.5665 - val_loss: 1.3845 - val_accuracy: 0.5600
# Epoch 99/200
# 7/7 [==============================] - 1s 206ms/step - loss: 1.1542 - accuracy: 0.5734 - val_loss: 1.3048 - val_accuracy: 0.6000
# Epoch 100/200
# 7/7 [==============================] - 1s 202ms/step - loss: 1.1299 - accuracy: 0.5665 - val_loss: 1.4911 - val_accuracy: 0.4600
# Epoch 101/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.0938 - accuracy: 0.5826 - val_loss: 1.5315 - val_accuracy: 0.5200
# Epoch 102/200
# 7/7 [==============================] - 1s 210ms/step - loss: 1.1358 - accuracy: 0.5573 - val_loss: 1.4860 - val_accuracy: 0.5800
# Epoch 103/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.1560 - accuracy: 0.5480 - val_loss: 1.5360 - val_accuracy: 0.4800
# Epoch 104/200
# 7/7 [==============================] - 2s 233ms/step - loss: 1.1426 - accuracy: 0.5700 - val_loss: 1.5393 - val_accuracy: 0.5400
# Epoch 105/200
# 7/7 [==============================] - 2s 252ms/step - loss: 1.1270 - accuracy: 0.5745 - val_loss: 1.3966 - val_accuracy: 0.5800
# Epoch 106/200
# 7/7 [==============================] - 2s 223ms/step - loss: 1.0738 - accuracy: 0.5849 - val_loss: 1.3555 - val_accuracy: 0.6000
# Epoch 107/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.1454 - accuracy: 0.5791 - val_loss: 1.4089 - val_accuracy: 0.6200
# Epoch 108/200
# 7/7 [==============================] - 2s 194ms/step - loss: 1.1004 - accuracy: 0.5915 - val_loss: 1.5694 - val_accuracy: 0.6200
# Epoch 109/200
# 7/7 [==============================] - 2s 230ms/step - loss: 1.1030 - accuracy: 0.5745 - val_loss: 1.5259 - val_accuracy: 0.6200
# Epoch 110/200
# 7/7 [==============================] - 2s 217ms/step - loss: 1.0505 - accuracy: 0.6055 - val_loss: 1.5738 - val_accuracy: 0.5400
# Epoch 111/200
# 7/7 [==============================] - 2s 217ms/step - loss: 1.1149 - accuracy: 0.5848 - val_loss: 1.4743 - val_accuracy: 0.5800
# Epoch 112/200
# 7/7 [==============================] - 2s 208ms/step - loss: 1.1190 - accuracy: 0.5768 - val_loss: 1.4724 - val_accuracy: 0.6400
# Epoch 113/200
# 7/7 [==============================] - 2s 217ms/step - loss: 1.0795 - accuracy: 0.5986 - val_loss: 1.5070 - val_accuracy: 0.5800
# Epoch 114/200
# 7/7 [==============================] - 2s 245ms/step - loss: 1.1015 - accuracy: 0.5642 - val_loss: 1.3659 - val_accuracy: 0.6000
# Epoch 115/200
# 7/7 [==============================] - 2s 221ms/step - loss: 1.0765 - accuracy: 0.5872 - val_loss: 1.2873 - val_accuracy: 0.4800
# Epoch 116/200
# 7/7 [==============================] - 2s 206ms/step - loss: 1.1008 - accuracy: 0.5748 - val_loss: 1.3652 - val_accuracy: 0.6000
# Epoch 117/200
# 7/7 [==============================] - 1s 208ms/step - loss: 1.0626 - accuracy: 0.6101 - val_loss: 1.5229 - val_accuracy: 0.6000
# Epoch 118/200
# 7/7 [==============================] - 1s 201ms/step - loss: 1.0538 - accuracy: 0.5906 - val_loss: 1.4164 - val_accuracy: 0.6000
# Epoch 119/200
# 7/7 [==============================] - 2s 215ms/step - loss: 1.0746 - accuracy: 0.5872 - val_loss: 1.5974 - val_accuracy: 0.5200
# Epoch 120/200
# 7/7 [==============================] - 2s 204ms/step - loss: 1.0987 - accuracy: 0.5562 - val_loss: 1.2948 - val_accuracy: 0.6000
# Epoch 121/200
# 7/7 [==============================] - 2s 232ms/step - loss: 1.0830 - accuracy: 0.6067 - val_loss: 1.3710 - val_accuracy: 0.6200
# Epoch 122/200
# 7/7 [==============================] - 2s 223ms/step - loss: 1.0854 - accuracy: 0.6067 - val_loss: 1.3098 - val_accuracy: 0.6400
# Epoch 123/200
# 7/7 [==============================] - 1s 191ms/step - loss: 1.0458 - accuracy: 0.6044 - val_loss: 1.5278 - val_accuracy: 0.6200
# Epoch 124/200
# 7/7 [==============================] - 2s 245ms/step - loss: 1.0438 - accuracy: 0.5998 - val_loss: 1.4681 - val_accuracy: 0.5800
# Epoch 125/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.0364 - accuracy: 0.5998 - val_loss: 1.5671 - val_accuracy: 0.5600
# Epoch 126/200
# 7/7 [==============================] - 1s 217ms/step - loss: 1.0696 - accuracy: 0.5975 - val_loss: 1.5231 - val_accuracy: 0.6000
# Epoch 127/200
# 7/7 [==============================] - 2s 207ms/step - loss: 1.1013 - accuracy: 0.5963 - val_loss: 1.2299 - val_accuracy: 0.6600
# Epoch 128/200
# 7/7 [==============================] - 1s 200ms/step - loss: 1.0798 - accuracy: 0.5837 - val_loss: 1.3306 - val_accuracy: 0.6200
# Epoch 129/200
# 7/7 [==============================] - 2s 212ms/step - loss: 1.0399 - accuracy: 0.6158 - val_loss: 1.3895 - val_accuracy: 0.6000
# Epoch 130/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.0524 - accuracy: 0.6193 - val_loss: 1.6123 - val_accuracy: 0.5800
# Epoch 131/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.0681 - accuracy: 0.5975 - val_loss: 1.4353 - val_accuracy: 0.5400
# Epoch 132/200
# 7/7 [==============================] - 1s 198ms/step - loss: 1.0478 - accuracy: 0.5837 - val_loss: 1.3169 - val_accuracy: 0.6400
# Epoch 133/200
# 7/7 [==============================] - 1s 201ms/step - loss: 1.0333 - accuracy: 0.6055 - val_loss: 1.4821 - val_accuracy: 0.6400
# Epoch 134/200
# 7/7 [==============================] - 2s 237ms/step - loss: 1.0860 - accuracy: 0.6055 - val_loss: 1.3605 - val_accuracy: 0.6200
# Epoch 135/200
# 7/7 [==============================] - 1s 214ms/step - loss: 1.0390 - accuracy: 0.6216 - val_loss: 1.2612 - val_accuracy: 0.6200
# Epoch 136/200
# 7/7 [==============================] - 1s 201ms/step - loss: 1.0417 - accuracy: 0.6204 - val_loss: 1.3598 - val_accuracy: 0.6000
# Epoch 137/200
# 7/7 [==============================] - 1s 194ms/step - loss: 1.0923 - accuracy: 0.5906 - val_loss: 1.3007 - val_accuracy: 0.6200
# Epoch 138/200
# 7/7 [==============================] - 1s 205ms/step - loss: 1.0608 - accuracy: 0.5883 - val_loss: 1.2797 - val_accuracy: 0.6200
# Epoch 139/200
# 7/7 [==============================] - 2s 207ms/step - loss: 1.1048 - accuracy: 0.5871 - val_loss: 1.2272 - val_accuracy: 0.5800
# Epoch 140/200
# 7/7 [==============================] - 2s 216ms/step - loss: 1.0163 - accuracy: 0.6284 - val_loss: 1.4589 - val_accuracy: 0.5800
# Epoch 141/200
# 7/7 [==============================] - 2s 226ms/step - loss: 1.0501 - accuracy: 0.5963 - val_loss: 1.3427 - val_accuracy: 0.5600
# Epoch 142/200
# 7/7 [==============================] - 2s 215ms/step - loss: 1.0025 - accuracy: 0.6124 - val_loss: 1.7196 - val_accuracy: 0.5200
# Epoch 143/200
# 7/7 [==============================] - 2s 236ms/step - loss: 1.0506 - accuracy: 0.6021 - val_loss: 1.4463 - val_accuracy: 0.5800
# Epoch 144/200
# 7/7 [==============================] - 2s 208ms/step - loss: 1.0934 - accuracy: 0.5837 - val_loss: 1.3597 - val_accuracy: 0.5600
# Epoch 145/200
# 7/7 [==============================] - 2s 237ms/step - loss: 1.0801 - accuracy: 0.5952 - val_loss: 1.3052 - val_accuracy: 0.5800
# Epoch 146/200
# 7/7 [==============================] - 2s 215ms/step - loss: 0.9783 - accuracy: 0.6204 - val_loss: 1.1880 - val_accuracy: 0.6400
# Epoch 147/200
# 7/7 [==============================] - 1s 216ms/step - loss: 1.0441 - accuracy: 0.6032 - val_loss: 1.0814 - val_accuracy: 0.6200
# Epoch 148/200
# 7/7 [==============================] - 2s 189ms/step - loss: 1.0750 - accuracy: 0.5849 - val_loss: 1.0850 - val_accuracy: 0.6200
# Epoch 149/200
# 7/7 [==============================] - 2s 216ms/step - loss: 1.0377 - accuracy: 0.5975 - val_loss: 1.2334 - val_accuracy: 0.6600
# Epoch 150/200
# 7/7 [==============================] - 1s 203ms/step - loss: 0.9748 - accuracy: 0.6399 - val_loss: 1.1984 - val_accuracy: 0.6200
# Epoch 151/200
# 7/7 [==============================] - 1s 197ms/step - loss: 1.0267 - accuracy: 0.6044 - val_loss: 1.3214 - val_accuracy: 0.6200
# Epoch 152/200
# 7/7 [==============================] - 2s 217ms/step - loss: 1.0424 - accuracy: 0.6044 - val_loss: 1.2486 - val_accuracy: 0.5800
# Epoch 153/200
# 7/7 [==============================] - 2s 252ms/step - loss: 1.0300 - accuracy: 0.6055 - val_loss: 1.3126 - val_accuracy: 0.5600
# Epoch 154/200
# 7/7 [==============================] - 2s 224ms/step - loss: 0.9897 - accuracy: 0.6204 - val_loss: 1.3494 - val_accuracy: 0.5400
# Epoch 155/200
# 7/7 [==============================] - 2s 222ms/step - loss: 1.0324 - accuracy: 0.6158 - val_loss: 1.2798 - val_accuracy: 0.6200
# Epoch 156/200
# 7/7 [==============================] - 2s 211ms/step - loss: 0.9645 - accuracy: 0.6101 - val_loss: 1.2759 - val_accuracy: 0.6000
# Epoch 157/200
# 7/7 [==============================] - 2s 211ms/step - loss: 1.0078 - accuracy: 0.6158 - val_loss: 1.4857 - val_accuracy: 0.6000
# Epoch 158/200
# 7/7 [==============================] - 1s 206ms/step - loss: 1.0570 - accuracy: 0.6124 - val_loss: 1.2167 - val_accuracy: 0.5800
# Epoch 159/200
# 7/7 [==============================] - 1s 214ms/step - loss: 1.1100 - accuracy: 0.5883 - val_loss: 1.2340 - val_accuracy: 0.6400
# Epoch 160/200
# 7/7 [==============================] - 1s 207ms/step - loss: 1.0325 - accuracy: 0.6101 - val_loss: 1.4684 - val_accuracy: 0.6000
# Epoch 161/200
# 7/7 [==============================] - 2s 215ms/step - loss: 1.0810 - accuracy: 0.5826 - val_loss: 1.6327 - val_accuracy: 0.5800
# Epoch 162/200
# 7/7 [==============================] - 2s 251ms/step - loss: 1.0876 - accuracy: 0.6044 - val_loss: 1.5504 - val_accuracy: 0.5200
# Epoch 163/200
# 7/7 [==============================] - 2s 216ms/step - loss: 1.0329 - accuracy: 0.5940 - val_loss: 1.3401 - val_accuracy: 0.6000
# Epoch 164/200
# 7/7 [==============================] - 2s 203ms/step - loss: 1.0108 - accuracy: 0.6307 - val_loss: 1.2942 - val_accuracy: 0.5800
# Epoch 165/200
# 7/7 [==============================] - 2s 214ms/step - loss: 1.0126 - accuracy: 0.6319 - val_loss: 1.4701 - val_accuracy: 0.5600
# Epoch 166/200
# 7/7 [==============================] - 1s 213ms/step - loss: 1.0318 - accuracy: 0.6365 - val_loss: 1.3357 - val_accuracy: 0.5800
# Epoch 167/200
# 7/7 [==============================] - 2s 215ms/step - loss: 1.0232 - accuracy: 0.6319 - val_loss: 1.2536 - val_accuracy: 0.6000
# Epoch 168/200
# 7/7 [==============================] - 1s 202ms/step - loss: 0.9455 - accuracy: 0.6468 - val_loss: 1.3491 - val_accuracy: 0.6600
# Epoch 169/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.0156 - accuracy: 0.6032 - val_loss: 1.3797 - val_accuracy: 0.6400
# Epoch 170/200
# 7/7 [==============================] - 2s 203ms/step - loss: 1.0257 - accuracy: 0.6124 - val_loss: 1.4092 - val_accuracy: 0.6200
# Epoch 171/200
# 7/7 [==============================] - 1s 208ms/step - loss: 0.9888 - accuracy: 0.6353 - val_loss: 1.5310 - val_accuracy: 0.6600
# Epoch 172/200
# 7/7 [==============================] - 2s 227ms/step - loss: 0.9779 - accuracy: 0.6158 - val_loss: 1.6031 - val_accuracy: 0.6000
# Epoch 173/200
# 7/7 [==============================] - 1s 204ms/step - loss: 1.0100 - accuracy: 0.6250 - val_loss: 1.4374 - val_accuracy: 0.6000
# Epoch 174/200
# 7/7 [==============================] - 1s 204ms/step - loss: 1.0200 - accuracy: 0.6227 - val_loss: 1.4713 - val_accuracy: 0.5600
# Epoch 175/200
# 7/7 [==============================] - 2s 207ms/step - loss: 0.9910 - accuracy: 0.6273 - val_loss: 1.5325 - val_accuracy: 0.5400
# Epoch 176/200
# 7/7 [==============================] - 1s 213ms/step - loss: 1.0411 - accuracy: 0.6089 - val_loss: 1.7486 - val_accuracy: 0.5200
# Epoch 177/200
# 7/7 [==============================] - 1s 196ms/step - loss: 1.0097 - accuracy: 0.6112 - val_loss: 1.5072 - val_accuracy: 0.6000
# Epoch 178/200
# 7/7 [==============================] - 2s 227ms/step - loss: 0.9882 - accuracy: 0.6067 - val_loss: 1.5145 - val_accuracy: 0.5400
# Epoch 179/200
# 7/7 [==============================] - 1s 202ms/step - loss: 0.9866 - accuracy: 0.6365 - val_loss: 1.3142 - val_accuracy: 0.6000
# Epoch 180/200
# 7/7 [==============================] - 2s 222ms/step - loss: 0.9808 - accuracy: 0.6273 - val_loss: 1.3755 - val_accuracy: 0.6200
# Epoch 181/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.9537 - accuracy: 0.6284 - val_loss: 1.3069 - val_accuracy: 0.6200
# Epoch 182/200
# 7/7 [==============================] - 2s 200ms/step - loss: 0.9115 - accuracy: 0.6551 - val_loss: 1.4729 - val_accuracy: 0.5800
# Epoch 183/200
# 7/7 [==============================] - 2s 217ms/step - loss: 0.9898 - accuracy: 0.6445 - val_loss: 1.4282 - val_accuracy: 0.6400
# Epoch 184/200
# 7/7 [==============================] - 1s 204ms/step - loss: 1.0422 - accuracy: 0.5906 - val_loss: 1.4592 - val_accuracy: 0.5800
# Epoch 185/200
# 7/7 [==============================] - 1s 196ms/step - loss: 1.0041 - accuracy: 0.6319 - val_loss: 1.3258 - val_accuracy: 0.5400
# Epoch 186/200
# 7/7 [==============================] - 1s 205ms/step - loss: 1.0070 - accuracy: 0.6350 - val_loss: 1.3445 - val_accuracy: 0.5600
# Epoch 187/200
# 7/7 [==============================] - 1s 202ms/step - loss: 1.0338 - accuracy: 0.5917 - val_loss: 1.3362 - val_accuracy: 0.5800
# Epoch 188/200
# 7/7 [==============================] - 2s 216ms/step - loss: 0.9924 - accuracy: 0.6216 - val_loss: 1.3910 - val_accuracy: 0.5800
# Epoch 189/200
# 7/7 [==============================] - 1s 198ms/step - loss: 0.9956 - accuracy: 0.6158 - val_loss: 1.2688 - val_accuracy: 0.6200
# Epoch 190/200
# 7/7 [==============================] - 2s 204ms/step - loss: 0.9817 - accuracy: 0.6284 - val_loss: 1.1784 - val_accuracy: 0.6400
# Epoch 191/200
# 7/7 [==============================] - 2s 242ms/step - loss: 1.0316 - accuracy: 0.6044 - val_loss: 1.2859 - val_accuracy: 0.6000
# Epoch 192/200
# 7/7 [==============================] - 2s 208ms/step - loss: 0.9692 - accuracy: 0.6411 - val_loss: 1.4278 - val_accuracy: 0.5400
# Epoch 193/200
# 7/7 [==============================] - 2s 228ms/step - loss: 1.0006 - accuracy: 0.6181 - val_loss: 1.3531 - val_accuracy: 0.5800
# Epoch 194/200
# 7/7 [==============================] - 2s 211ms/step - loss: 0.9741 - accuracy: 0.6373 - val_loss: 1.3749 - val_accuracy: 0.6200
# Epoch 195/200
# 7/7 [==============================] - 2s 200ms/step - loss: 0.9739 - accuracy: 0.6227 - val_loss: 1.2049 - val_accuracy: 0.6400
# Epoch 196/200
# 7/7 [==============================] - 2s 221ms/step - loss: 0.9657 - accuracy: 0.6216 - val_loss: 1.2597 - val_accuracy: 0.5800
# Epoch 197/200
# 7/7 [==============================] - 1s 200ms/step - loss: 0.9859 - accuracy: 0.6296 - val_loss: 1.1580 - val_accuracy: 0.7400
# Epoch 198/200
# 7/7 [==============================] - 1s 212ms/step - loss: 0.9386 - accuracy: 0.6491 - val_loss: 1.1496 - val_accuracy: 0.7400
# Epoch 199/200
# 7/7 [==============================] - 1s 203ms/step - loss: 0.9868 - accuracy: 0.6261 - val_loss: 1.2604 - val_accuracy: 0.6400
# Epoch 200/200
# 7/7 [==============================] - 2s 237ms/step - loss: 0.9731 - accuracy: 0.6273 - val_loss: 1.0894 - val_accuracy: 0.7200

# %%
def plot_accuracy(history):
    acc = 'acc' if 'acc' in history else 'accuracy'
    val_acc = 'val_' + acc
    
    plt.plot(range(len(history[acc])), history[acc], color='b')
    plt.plot(range(len(history[val_acc])), history[val_acc], color='g')

    return hist.history[val_acc][-1]

plot_accuracy(hist.history)
# Out:
# 0.7200000286102295

# %% [markdown]
# Для проверки сохраняются веса сети, а также предсказания для тестовых данных:

# %%
fashion_clf.save("fashion_model.h5")

test_predictions = fashion_clf.predict(test_fashion_images)
np.save("submission", test_predictions)

# %% [markdown]
# Файлы `fashion_model.h5` и `submission.npy` необходимо добавить в репозиторий вместе с решением.
#
# Любые попытки получить более точную модель не с помощью аугментации запрещены.
#
# ---
#
# ## Выбор подходящей модели машинного обучения
#
# Возьмём набор данных `wine`

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

wine_x, wine_y = load_wine(return_X_y=True)

x_train, x_test, y_train, y_test = train_test_split(wine_x, wine_y, test_size=0.2, random_state=123456)
print(x_train[0])
# Out:
# [1.327e+01 4.280e+00 2.260e+00 2.000e+01 1.200e+02 1.590e+00 6.900e-01
#  4.300e-01 1.350e+00 1.020e+01 5.900e-01 1.560e+00 8.350e+02]

# %% [markdown]
# ---
#
# #### Задание 5 (дополнительное).
#
# Подберите модель машинного обучения для решения задачи _регрессии_ на данных из датасета `wine`.
#
# Обучите выбранную модель, используя для обучения только данные `x_train`, `y_train`.
#
# Данные `x_test`, `y_test` можно использовать в обучении _только в качестве валидационных данных_.
#
# Метрика MAE (mean absolute error, средняя квадратическая ошибка) на тестовых данных (`x_test`, `y_test`) должна быть меньше `0.1`.
#
# _За выполнение этого задания можно получить 1 дополнительный балл, но выполнять это задание не обязательно_

# %%
# Ваш код обучения модели
wine_regressor = Sequential([
    Dense(256, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)])
                            
wine_regressor.compile(loss='mae',
                optimizer='adam',
                metrics=['mae'])
wine_regressor.fit(x_train, y_train, epochs=1250, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1250
# 5/5 [==============================] - 1s 55ms/step - loss: 6.4583 - mae: 6.4583 - val_loss: 1.6910 - val_mae: 1.6910
# Epoch 2/1250
# 5/5 [==============================] - 0s 32ms/step - loss: 1.7713 - mae: 1.7713 - val_loss: 0.9941 - val_mae: 0.9941
# Epoch 3/1250
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7063 - mae: 1.7063 - val_loss: 2.1899 - val_mae: 2.1899
# Epoch 4/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 1.9901 - mae: 1.9901 - val_loss: 0.7722 - val_mae: 0.7722
# Epoch 5/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 1.3674 - mae: 1.3674 - val_loss: 1.1241 - val_mae: 1.1241
# Epoch 6/1250
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9861 - mae: 0.9861 - val_loss: 0.6676 - val_mae: 0.6676
# Epoch 7/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7377 - mae: 0.7377 - val_loss: 0.5185 - val_mae: 0.5185
# Epoch 8/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5791 - mae: 0.5791 - val_loss: 0.6825 - val_mae: 0.6825
# Epoch 9/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7117 - mae: 0.7117 - val_loss: 0.7094 - val_mae: 0.7094
# Epoch 10/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8265 - mae: 0.8265 - val_loss: 0.5169 - val_mae: 0.5169
# Epoch 11/1250
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9801 - mae: 0.9801 - val_loss: 0.4577 - val_mae: 0.4577
# Epoch 12/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7102 - mae: 0.7102 - val_loss: 0.6752 - val_mae: 0.6752
# Epoch 13/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6195 - mae: 0.6195 - val_loss: 1.0913 - val_mae: 1.0913
# Epoch 14/1250
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8221 - mae: 0.8221 - val_loss: 0.5183 - val_mae: 0.5183
# Epoch 15/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5714 - mae: 0.5714 - val_loss: 0.4221 - val_mae: 0.4221
# Epoch 16/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5633 - mae: 0.5633 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 17/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5650 - mae: 0.5650 - val_loss: 0.8452 - val_mae: 0.8452
# Epoch 18/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9753 - mae: 0.9753 - val_loss: 1.1272 - val_mae: 1.1272
# Epoch 19/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8217 - mae: 0.8217 - val_loss: 0.8802 - val_mae: 0.8802
# Epoch 20/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0144 - mae: 1.0144 - val_loss: 1.3376 - val_mae: 1.3376
# Epoch 21/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9087 - mae: 0.9087 - val_loss: 1.1523 - val_mae: 1.1523
# Epoch 22/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6900 - mae: 0.6900 - val_loss: 0.3797 - val_mae: 0.3797
# Epoch 23/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4621 - mae: 0.4621 - val_loss: 0.5853 - val_mae: 0.5853
# Epoch 24/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5926 - mae: 0.5926 - val_loss: 0.3765 - val_mae: 0.3765
# Epoch 25/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5120 - mae: 0.5120 - val_loss: 0.5229 - val_mae: 0.5229
# Epoch 26/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4978 - mae: 0.4978 - val_loss: 0.3785 - val_mae: 0.3785
# Epoch 27/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4634 - mae: 0.4634 - val_loss: 0.6189 - val_mae: 0.6189
# Epoch 28/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5358 - mae: 0.5358 - val_loss: 0.3898 - val_mae: 0.3898
# Epoch 29/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5103 - mae: 0.5103 - val_loss: 0.5256 - val_mae: 0.5256
# Epoch 30/1250
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5636 - mae: 0.5636 - val_loss: 0.3452 - val_mae: 0.3452
# Epoch 31/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5385 - mae: 0.5385 - val_loss: 0.5691 - val_mae: 0.5691
# Epoch 32/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6688 - mae: 0.6688 - val_loss: 0.9471 - val_mae: 0.9471
# Epoch 33/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8656 - mae: 0.8656 - val_loss: 0.7923 - val_mae: 0.7923
# Epoch 34/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6845 - mae: 0.6845 - val_loss: 0.4044 - val_mae: 0.4044
# Epoch 35/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5049 - mae: 0.5049 - val_loss: 0.7441 - val_mae: 0.7441
# Epoch 36/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8677 - mae: 0.8677 - val_loss: 0.9945 - val_mae: 0.9945
# Epoch 37/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6731 - mae: 0.6731 - val_loss: 0.3598 - val_mae: 0.3598
# Epoch 38/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.9876 - mae: 0.9876 - val_loss: 0.3385 - val_mae: 0.3385
# Epoch 39/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.9667 - mae: 0.9667 - val_loss: 0.6178 - val_mae: 0.6178
# Epoch 40/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9956 - mae: 0.9956 - val_loss: 1.3498 - val_mae: 1.3498
# Epoch 41/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 1.1994 - mae: 1.1994 - val_loss: 1.3047 - val_mae: 1.3047
# Epoch 42/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 1.3538 - mae: 1.3538 - val_loss: 0.9811 - val_mae: 0.9811
# Epoch 43/1250
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9668 - mae: 0.9668 - val_loss: 1.3397 - val_mae: 1.3397
# Epoch 44/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 1.4540 - mae: 1.4540 - val_loss: 0.5943 - val_mae: 0.5943
# Epoch 45/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8767 - mae: 0.8767 - val_loss: 0.5122 - val_mae: 0.5122
# Epoch 46/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9701 - mae: 0.9701 - val_loss: 1.2625 - val_mae: 1.2625
# Epoch 47/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.8939 - mae: 0.8939 - val_loss: 0.6215 - val_mae: 0.6215
# Epoch 48/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6024 - mae: 0.6024 - val_loss: 0.4114 - val_mae: 0.4114
# Epoch 49/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4430 - mae: 0.4430 - val_loss: 0.6662 - val_mae: 0.6662
# Epoch 50/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6760 - mae: 0.6760 - val_loss: 0.5828 - val_mae: 0.5828
# Epoch 51/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5749 - mae: 0.5749 - val_loss: 0.6829 - val_mae: 0.6829
# Epoch 52/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6213 - mae: 0.6213 - val_loss: 0.4308 - val_mae: 0.4308
# Epoch 53/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4121 - mae: 0.4121 - val_loss: 0.3681 - val_mae: 0.3681
# Epoch 54/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3944 - mae: 0.3944 - val_loss: 0.6840 - val_mae: 0.6840
# Epoch 55/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5718 - mae: 0.5718 - val_loss: 0.5984 - val_mae: 0.5984
# Epoch 56/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4671 - mae: 0.4671 - val_loss: 0.6306 - val_mae: 0.6306
# Epoch 57/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5645 - mae: 0.5645 - val_loss: 0.5192 - val_mae: 0.5192
# Epoch 58/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4462 - mae: 0.4462 - val_loss: 0.4125 - val_mae: 0.4125
# Epoch 59/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3682 - mae: 0.3682 - val_loss: 0.3088 - val_mae: 0.3088
# Epoch 60/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3334 - mae: 0.3334 - val_loss: 0.3386 - val_mae: 0.3386
# Epoch 61/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4005 - mae: 0.4005 - val_loss: 0.4151 - val_mae: 0.4151
# Epoch 62/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4151 - mae: 0.4151 - val_loss: 0.5081 - val_mae: 0.5081
# Epoch 63/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5140 - mae: 0.5140 - val_loss: 0.7628 - val_mae: 0.7628
# Epoch 64/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6133 - mae: 0.6133 - val_loss: 0.8622 - val_mae: 0.8622
# Epoch 65/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8629 - mae: 0.8629 - val_loss: 0.7948 - val_mae: 0.7948
# Epoch 66/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7645 - mae: 0.7645 - val_loss: 0.3201 - val_mae: 0.3201
# Epoch 67/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6409 - mae: 0.6409 - val_loss: 0.3174 - val_mae: 0.3174
# Epoch 68/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4248 - mae: 0.4248 - val_loss: 0.5572 - val_mae: 0.5572
# Epoch 69/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5094 - mae: 0.5094 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 70/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5031 - mae: 0.5031 - val_loss: 0.5564 - val_mae: 0.5564
# Epoch 71/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4172 - mae: 0.4172 - val_loss: 0.2955 - val_mae: 0.2955
# Epoch 72/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3303 - mae: 0.3303 - val_loss: 0.6803 - val_mae: 0.6803
# Epoch 73/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8385 - mae: 0.8385 - val_loss: 0.5700 - val_mae: 0.5700
# Epoch 74/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6160 - mae: 0.6160 - val_loss: 0.5968 - val_mae: 0.5968
# Epoch 75/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7560 - mae: 0.7560 - val_loss: 0.5738 - val_mae: 0.5738
# Epoch 76/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6787 - mae: 0.6787 - val_loss: 0.8542 - val_mae: 0.8542
# Epoch 77/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8358 - mae: 0.8358 - val_loss: 0.8304 - val_mae: 0.8304
# Epoch 78/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9600 - mae: 0.9600 - val_loss: 0.6896 - val_mae: 0.6896
# Epoch 79/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5363 - mae: 0.5363 - val_loss: 0.6423 - val_mae: 0.6423
# Epoch 80/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5597 - mae: 0.5597 - val_loss: 0.6263 - val_mae: 0.6263
# Epoch 81/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5419 - mae: 0.5419 - val_loss: 0.6417 - val_mae: 0.6417
# Epoch 82/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5912 - mae: 0.5912 - val_loss: 0.3409 - val_mae: 0.3409
# Epoch 83/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3707 - mae: 0.3707 - val_loss: 0.3520 - val_mae: 0.3520
# Epoch 84/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4435 - mae: 0.4435 - val_loss: 0.4108 - val_mae: 0.4108
# Epoch 85/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3531 - mae: 0.3531 - val_loss: 0.3259 - val_mae: 0.3259
# Epoch 86/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3343 - mae: 0.3343 - val_loss: 0.4634 - val_mae: 0.4634
# Epoch 87/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4102 - mae: 0.4102 - val_loss: 0.5439 - val_mae: 0.5439
# Epoch 88/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4983 - mae: 0.4983 - val_loss: 0.3258 - val_mae: 0.3258
# Epoch 89/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4192 - mae: 0.4192 - val_loss: 0.2963 - val_mae: 0.2963
# Epoch 90/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3532 - mae: 0.3532 - val_loss: 0.3659 - val_mae: 0.3659
# Epoch 91/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3260 - mae: 0.3260 - val_loss: 0.3088 - val_mae: 0.3088
# Epoch 92/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3346 - mae: 0.3346 - val_loss: 0.3519 - val_mae: 0.3519
# Epoch 93/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4212 - mae: 0.4212 - val_loss: 0.2889 - val_mae: 0.2889
# Epoch 94/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3255 - mae: 0.3255 - val_loss: 0.4731 - val_mae: 0.4731
# Epoch 95/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4493 - mae: 0.4493 - val_loss: 0.3200 - val_mae: 0.3200
# Epoch 96/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3382 - mae: 0.3382 - val_loss: 0.2848 - val_mae: 0.2848
# Epoch 97/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3574 - mae: 0.3574 - val_loss: 0.3440 - val_mae: 0.3440
# Epoch 98/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3980 - mae: 0.3980 - val_loss: 0.2538 - val_mae: 0.2538
# Epoch 99/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4272 - mae: 0.4272 - val_loss: 0.3413 - val_mae: 0.3413
# Epoch 100/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3392 - mae: 0.3392 - val_loss: 0.7153 - val_mae: 0.7153
# Epoch 101/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6303 - mae: 0.6303 - val_loss: 0.5532 - val_mae: 0.5532
# Epoch 102/1250
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6386 - mae: 0.6386 - val_loss: 0.4059 - val_mae: 0.4059
# Epoch 103/1250
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5137 - mae: 0.5137 - val_loss: 0.8192 - val_mae: 0.8192
# Epoch 104/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6614 - mae: 0.6614 - val_loss: 0.3657 - val_mae: 0.3657
# Epoch 105/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3876 - mae: 0.3876 - val_loss: 0.2544 - val_mae: 0.2544
# Epoch 106/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3773 - mae: 0.3773 - val_loss: 0.2636 - val_mae: 0.2636
# Epoch 107/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3567 - mae: 0.3567 - val_loss: 0.2871 - val_mae: 0.2871
# Epoch 108/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3857 - mae: 0.3857 - val_loss: 0.3866 - val_mae: 0.3866
# Epoch 109/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3925 - mae: 0.3925 - val_loss: 0.4287 - val_mae: 0.4287
# Epoch 110/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4285 - mae: 0.4285 - val_loss: 0.3430 - val_mae: 0.3430
# Epoch 111/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3600 - mae: 0.3600 - val_loss: 0.2727 - val_mae: 0.2727
# Epoch 112/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3298 - mae: 0.3298 - val_loss: 0.2950 - val_mae: 0.2950
# Epoch 113/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3318 - mae: 0.3318 - val_loss: 0.2502 - val_mae: 0.2502
# Epoch 114/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3114 - mae: 0.3114 - val_loss: 0.2783 - val_mae: 0.2783
# Epoch 115/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2695 - mae: 0.2695 - val_loss: 0.2441 - val_mae: 0.2441
# Epoch 116/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2630 - mae: 0.2630 - val_loss: 0.2617 - val_mae: 0.2617
# Epoch 117/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2581 - mae: 0.2581 - val_loss: 0.2494 - val_mae: 0.2494
# Epoch 118/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2633 - mae: 0.2633 - val_loss: 0.4353 - val_mae: 0.4353
# Epoch 119/1250
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3801 - mae: 0.3801 - val_loss: 0.2534 - val_mae: 0.2534
# Epoch 120/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2838 - mae: 0.2838 - val_loss: 0.2770 - val_mae: 0.2770
# Epoch 121/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2948 - mae: 0.2948 - val_loss: 0.2403 - val_mae: 0.2403
# Epoch 122/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2514 - mae: 0.2514 - val_loss: 0.3320 - val_mae: 0.3320
# Epoch 123/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3561 - mae: 0.3561 - val_loss: 0.2825 - val_mae: 0.2825
# Epoch 124/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4678 - mae: 0.4678 - val_loss: 0.4411 - val_mae: 0.4411
# Epoch 125/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3986 - mae: 0.3986 - val_loss: 0.4595 - val_mae: 0.4595
# Epoch 126/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3933 - mae: 0.3933 - val_loss: 0.3907 - val_mae: 0.3907
# Epoch 127/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3688 - mae: 0.3688 - val_loss: 0.5590 - val_mae: 0.5590
# Epoch 128/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4234 - mae: 0.4234 - val_loss: 0.3639 - val_mae: 0.3639
# Epoch 129/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3060 - mae: 0.3060 - val_loss: 0.2619 - val_mae: 0.2619
# Epoch 130/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2878 - mae: 0.2878 - val_loss: 0.2245 - val_mae: 0.2245
# Epoch 131/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3318 - mae: 0.3318 - val_loss: 0.2447 - val_mae: 0.2447
# Epoch 132/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2808 - mae: 0.2808 - val_loss: 0.3825 - val_mae: 0.3825
# Epoch 133/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3345 - mae: 0.3345 - val_loss: 0.3612 - val_mae: 0.3612
# Epoch 134/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4113 - mae: 0.4113 - val_loss: 0.4159 - val_mae: 0.4159
# Epoch 135/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3382 - mae: 0.3382 - val_loss: 0.2671 - val_mae: 0.2671
# Epoch 136/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3050 - mae: 0.3050 - val_loss: 0.2561 - val_mae: 0.2561
# Epoch 137/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2935 - mae: 0.2935 - val_loss: 0.3570 - val_mae: 0.3570
# Epoch 138/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2916 - mae: 0.2916 - val_loss: 0.2749 - val_mae: 0.2749
# Epoch 139/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2574 - mae: 0.2574 - val_loss: 0.2207 - val_mae: 0.2207
# Epoch 140/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2682 - mae: 0.2682 - val_loss: 0.2945 - val_mae: 0.2945
# Epoch 141/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3182 - mae: 0.3182 - val_loss: 0.2735 - val_mae: 0.2735
# Epoch 142/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2844 - mae: 0.2844 - val_loss: 0.3425 - val_mae: 0.3425
# Epoch 143/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2969 - mae: 0.2969 - val_loss: 0.2810 - val_mae: 0.2810
# Epoch 144/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2603 - mae: 0.2603 - val_loss: 0.3676 - val_mae: 0.3676
# Epoch 145/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3324 - mae: 0.3324 - val_loss: 0.2210 - val_mae: 0.2210
# Epoch 146/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3441 - mae: 0.3441 - val_loss: 0.3550 - val_mae: 0.3550
# Epoch 147/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3388 - mae: 0.3388 - val_loss: 0.2861 - val_mae: 0.2861
# Epoch 148/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2503 - mae: 0.2503 - val_loss: 0.2207 - val_mae: 0.2207
# Epoch 149/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2748 - mae: 0.2748 - val_loss: 0.2225 - val_mae: 0.2225
# Epoch 150/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2473 - mae: 0.2473 - val_loss: 0.2793 - val_mae: 0.2793
# Epoch 151/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2521 - mae: 0.2521 - val_loss: 0.2471 - val_mae: 0.2471
# Epoch 152/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2517 - mae: 0.2517 - val_loss: 0.4135 - val_mae: 0.4135
# Epoch 153/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3406 - mae: 0.3406 - val_loss: 0.3586 - val_mae: 0.3586
# Epoch 154/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3336 - mae: 0.3336 - val_loss: 0.2317 - val_mae: 0.2317
# Epoch 155/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2712 - mae: 0.2712 - val_loss: 0.2250 - val_mae: 0.2250
# Epoch 156/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2427 - mae: 0.2427 - val_loss: 0.2176 - val_mae: 0.2176
# Epoch 157/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3138 - mae: 0.3138 - val_loss: 0.2466 - val_mae: 0.2466
# Epoch 158/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3935 - mae: 0.3935 - val_loss: 0.2487 - val_mae: 0.2487
# Epoch 159/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5339 - mae: 0.5339 - val_loss: 0.9074 - val_mae: 0.9074
# Epoch 160/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7962 - mae: 0.7962 - val_loss: 0.8171 - val_mae: 0.8171
# Epoch 161/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6623 - mae: 0.6623 - val_loss: 0.3418 - val_mae: 0.3418
# Epoch 162/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4266 - mae: 0.4266 - val_loss: 0.3214 - val_mae: 0.3214
# Epoch 163/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4912 - mae: 0.4912 - val_loss: 0.5237 - val_mae: 0.5237
# Epoch 164/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5523 - mae: 0.5523 - val_loss: 0.3294 - val_mae: 0.3294
# Epoch 165/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4279 - mae: 0.4279 - val_loss: 0.5493 - val_mae: 0.5493
# Epoch 166/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4346 - mae: 0.4346 - val_loss: 0.2545 - val_mae: 0.2545
# Epoch 167/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2853 - mae: 0.2853 - val_loss: 0.2840 - val_mae: 0.2840
# Epoch 168/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3041 - mae: 0.3041 - val_loss: 0.2312 - val_mae: 0.2312
# Epoch 169/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2952 - mae: 0.2952 - val_loss: 0.3111 - val_mae: 0.3111
# Epoch 170/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3165 - mae: 0.3165 - val_loss: 0.3427 - val_mae: 0.3427
# Epoch 171/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3944 - mae: 0.3944 - val_loss: 0.2749 - val_mae: 0.2749
# Epoch 172/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5323 - mae: 0.5323 - val_loss: 0.3575 - val_mae: 0.3575
# Epoch 173/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2896 - mae: 0.2896 - val_loss: 0.3985 - val_mae: 0.3985
# Epoch 174/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3653 - mae: 0.3653 - val_loss: 0.3441 - val_mae: 0.3441
# Epoch 175/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3789 - mae: 0.3789 - val_loss: 0.4545 - val_mae: 0.4545
# Epoch 176/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3685 - mae: 0.3685 - val_loss: 0.3107 - val_mae: 0.3107
# Epoch 177/1250
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2741 - mae: 0.2741 - val_loss: 0.4376 - val_mae: 0.4376
# Epoch 178/1250
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3003 - mae: 0.3003 - val_loss: 0.2848 - val_mae: 0.2848
# Epoch 179/1250
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5879 - mae: 0.5879 - val_loss: 0.2893 - val_mae: 0.2893
# Epoch 180/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5951 - mae: 0.5951 - val_loss: 0.2386 - val_mae: 0.2386
# Epoch 181/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5495 - mae: 0.5495 - val_loss: 0.3382 - val_mae: 0.3382
# Epoch 182/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5321 - mae: 0.5321 - val_loss: 0.4941 - val_mae: 0.4941
# Epoch 183/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5166 - mae: 0.5166 - val_loss: 0.6092 - val_mae: 0.6092
# Epoch 184/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4780 - mae: 0.4780 - val_loss: 0.4486 - val_mae: 0.4486
# Epoch 185/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4916 - mae: 0.4916 - val_loss: 0.4907 - val_mae: 0.4907
# Epoch 186/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6898 - mae: 0.6898 - val_loss: 0.4329 - val_mae: 0.4329
# Epoch 187/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5036 - mae: 0.5036 - val_loss: 0.3600 - val_mae: 0.3600
# Epoch 188/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4658 - mae: 0.4658 - val_loss: 0.2754 - val_mae: 0.2754
# Epoch 189/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4385 - mae: 0.4385 - val_loss: 0.2772 - val_mae: 0.2772
# Epoch 190/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4463 - mae: 0.4463 - val_loss: 0.3289 - val_mae: 0.3289
# Epoch 191/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5208 - mae: 0.5208 - val_loss: 0.7268 - val_mae: 0.7268
# Epoch 192/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6062 - mae: 0.6062 - val_loss: 0.8584 - val_mae: 0.8584
# Epoch 193/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6694 - mae: 0.6694 - val_loss: 0.8231 - val_mae: 0.8231
# Epoch 194/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6613 - mae: 0.6613 - val_loss: 0.9078 - val_mae: 0.9078
# Epoch 195/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7262 - mae: 0.7262 - val_loss: 0.7716 - val_mae: 0.7716
# Epoch 196/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7057 - mae: 0.7057 - val_loss: 0.3442 - val_mae: 0.3442
# Epoch 197/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5563 - mae: 0.5563 - val_loss: 0.7189 - val_mae: 0.7189
# Epoch 198/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6272 - mae: 0.6272 - val_loss: 0.4648 - val_mae: 0.4648
# Epoch 199/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6574 - mae: 0.6574 - val_loss: 0.5268 - val_mae: 0.5268
# Epoch 200/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5541 - mae: 0.5541 - val_loss: 0.3914 - val_mae: 0.3914
# Epoch 201/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3428 - mae: 0.3428 - val_loss: 0.2854 - val_mae: 0.2854
# Epoch 202/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3150 - mae: 0.3150 - val_loss: 0.2293 - val_mae: 0.2293
# Epoch 203/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2873 - mae: 0.2873 - val_loss: 0.2692 - val_mae: 0.2692
# Epoch 204/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3551 - mae: 0.3551 - val_loss: 0.2804 - val_mae: 0.2804
# Epoch 205/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4429 - mae: 0.4429 - val_loss: 0.3613 - val_mae: 0.3613
# Epoch 206/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4233 - mae: 0.4233 - val_loss: 0.3132 - val_mae: 0.3132
# Epoch 207/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3598 - mae: 0.3598 - val_loss: 0.4307 - val_mae: 0.4307
# Epoch 208/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6735 - mae: 0.6735 - val_loss: 0.8627 - val_mae: 0.8627
# Epoch 209/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5813 - mae: 0.5813 - val_loss: 0.2505 - val_mae: 0.2505
# Epoch 210/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5215 - mae: 0.5215 - val_loss: 1.0177 - val_mae: 1.0177
# Epoch 211/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5965 - mae: 0.5965 - val_loss: 0.3024 - val_mae: 0.3024
# Epoch 212/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3232 - mae: 0.3232 - val_loss: 0.2784 - val_mae: 0.2784
# Epoch 213/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3973 - mae: 0.3973 - val_loss: 0.3017 - val_mae: 0.3017
# Epoch 214/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3287 - mae: 0.3287 - val_loss: 0.3968 - val_mae: 0.3968
# Epoch 215/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4201 - mae: 0.4201 - val_loss: 0.3752 - val_mae: 0.3752
# Epoch 216/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3596 - mae: 0.3596 - val_loss: 0.2868 - val_mae: 0.2868
# Epoch 217/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3230 - mae: 0.3230 - val_loss: 0.2497 - val_mae: 0.2497
# Epoch 218/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2789 - mae: 0.2789 - val_loss: 0.2544 - val_mae: 0.2544
# Epoch 219/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2733 - mae: 0.2733 - val_loss: 0.2515 - val_mae: 0.2515
# Epoch 220/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2608 - mae: 0.2608 - val_loss: 0.2462 - val_mae: 0.2462
# Epoch 221/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2716 - mae: 0.2716 - val_loss: 0.2828 - val_mae: 0.2828
# Epoch 222/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2986 - mae: 0.2986 - val_loss: 0.3194 - val_mae: 0.3194
# Epoch 223/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3099 - mae: 0.3099 - val_loss: 0.2805 - val_mae: 0.2805
# Epoch 224/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3100 - mae: 0.3100 - val_loss: 0.2897 - val_mae: 0.2897
# Epoch 225/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2771 - mae: 0.2771 - val_loss: 0.2690 - val_mae: 0.2690
# Epoch 226/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2817 - mae: 0.2817 - val_loss: 0.3293 - val_mae: 0.3293
# Epoch 227/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3146 - mae: 0.3146 - val_loss: 0.2387 - val_mae: 0.2387
# Epoch 228/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2651 - mae: 0.2651 - val_loss: 0.2281 - val_mae: 0.2281
# Epoch 229/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2297 - mae: 0.2297 - val_loss: 0.2261 - val_mae: 0.2261
# Epoch 230/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2319 - mae: 0.2319 - val_loss: 0.2677 - val_mae: 0.2677
# Epoch 231/1250
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2605 - mae: 0.2605 - val_loss: 0.3082 - val_mae: 0.3082
# Epoch 232/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3419 - mae: 0.3419 - val_loss: 0.2235 - val_mae: 0.2235
# Epoch 233/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2774 - mae: 0.2774 - val_loss: 0.2190 - val_mae: 0.2190
# Epoch 234/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2344 - mae: 0.2344 - val_loss: 0.2380 - val_mae: 0.2380
# Epoch 235/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2385 - mae: 0.2385 - val_loss: 0.2358 - val_mae: 0.2358
# Epoch 236/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2584 - mae: 0.2584 - val_loss: 0.2606 - val_mae: 0.2606
# Epoch 237/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2367 - mae: 0.2367 - val_loss: 0.2802 - val_mae: 0.2802
# Epoch 238/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2566 - mae: 0.2566 - val_loss: 0.3651 - val_mae: 0.3651
# Epoch 239/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4037 - mae: 0.4037 - val_loss: 0.4989 - val_mae: 0.4989
# Epoch 240/1250
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4710 - mae: 0.4710 - val_loss: 0.2473 - val_mae: 0.2473
# Epoch 241/1250
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5130 - mae: 0.5130 - val_loss: 0.5320 - val_mae: 0.5320
# Epoch 242/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5505 - mae: 0.5505 - val_loss: 0.6144 - val_mae: 0.6144
# Epoch 243/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4653 - mae: 0.4653 - val_loss: 0.4335 - val_mae: 0.4335
# Epoch 244/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3864 - mae: 0.3864 - val_loss: 0.2227 - val_mae: 0.2227
# Epoch 245/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3002 - mae: 0.3002 - val_loss: 0.2265 - val_mae: 0.2265
# Epoch 246/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2835 - mae: 0.2835 - val_loss: 0.2177 - val_mae: 0.2177
# Epoch 247/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2645 - mae: 0.2645 - val_loss: 0.2213 - val_mae: 0.2213
# Epoch 248/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2577 - mae: 0.2577 - val_loss: 0.2292 - val_mae: 0.2292
# Epoch 249/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2560 - mae: 0.2560 - val_loss: 0.2867 - val_mae: 0.2867
# Epoch 250/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2531 - mae: 0.2531 - val_loss: 0.2568 - val_mae: 0.2568
# Epoch 251/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2406 - mae: 0.2406 - val_loss: 0.2146 - val_mae: 0.2146
# Epoch 252/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2233 - mae: 0.2233 - val_loss: 0.2463 - val_mae: 0.2463
# Epoch 253/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2519 - mae: 0.2519 - val_loss: 0.2692 - val_mae: 0.2692
# Epoch 254/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3436 - mae: 0.3436 - val_loss: 0.3151 - val_mae: 0.3151
# Epoch 255/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3230 - mae: 0.3230 - val_loss: 0.3386 - val_mae: 0.3386
# Epoch 256/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3506 - mae: 0.3506 - val_loss: 0.3622 - val_mae: 0.3622
# Epoch 257/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3763 - mae: 0.3763 - val_loss: 0.2257 - val_mae: 0.2257
# Epoch 258/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3088 - mae: 0.3088 - val_loss: 0.2346 - val_mae: 0.2346
# Epoch 259/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2659 - mae: 0.2659 - val_loss: 0.3720 - val_mae: 0.3720
# Epoch 260/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3612 - mae: 0.3612 - val_loss: 0.2141 - val_mae: 0.2141
# Epoch 261/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3089 - mae: 0.3089 - val_loss: 0.3761 - val_mae: 0.3761
# Epoch 262/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3273 - mae: 0.3273 - val_loss: 0.2585 - val_mae: 0.2585
# Epoch 263/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3073 - mae: 0.3073 - val_loss: 0.4338 - val_mae: 0.4338
# Epoch 264/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3694 - mae: 0.3694 - val_loss: 0.2083 - val_mae: 0.2083
# Epoch 265/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2630 - mae: 0.2630 - val_loss: 0.2606 - val_mae: 0.2606
# Epoch 266/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2821 - mae: 0.2821 - val_loss: 0.2990 - val_mae: 0.2990
# Epoch 267/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3132 - mae: 0.3132 - val_loss: 0.2226 - val_mae: 0.2226
# Epoch 268/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3415 - mae: 0.3415 - val_loss: 0.4174 - val_mae: 0.4174
# Epoch 269/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3711 - mae: 0.3711 - val_loss: 0.2425 - val_mae: 0.2425
# Epoch 270/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2682 - mae: 0.2682 - val_loss: 0.2931 - val_mae: 0.2931
# Epoch 271/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3097 - mae: 0.3097 - val_loss: 0.2325 - val_mae: 0.2325
# Epoch 272/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2351 - mae: 0.2351 - val_loss: 0.1934 - val_mae: 0.1934
# Epoch 273/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2181 - mae: 0.2181 - val_loss: 0.3226 - val_mae: 0.3226
# Epoch 274/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3318 - mae: 0.3318 - val_loss: 0.2858 - val_mae: 0.2858
# Epoch 275/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2680 - mae: 0.2680 - val_loss: 0.2715 - val_mae: 0.2715
# Epoch 276/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2357 - mae: 0.2357 - val_loss: 0.2589 - val_mae: 0.2589
# Epoch 277/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2834 - mae: 0.2834 - val_loss: 0.1999 - val_mae: 0.1999
# Epoch 278/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2688 - mae: 0.2688 - val_loss: 0.2762 - val_mae: 0.2762
# Epoch 279/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2591 - mae: 0.2591 - val_loss: 0.2180 - val_mae: 0.2180
# Epoch 280/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2376 - mae: 0.2376 - val_loss: 0.2565 - val_mae: 0.2565
# Epoch 281/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2556 - mae: 0.2556 - val_loss: 0.2358 - val_mae: 0.2358
# Epoch 282/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2994 - mae: 0.2994 - val_loss: 0.3831 - val_mae: 0.3831
# Epoch 283/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3603 - mae: 0.3603 - val_loss: 0.2391 - val_mae: 0.2391
# Epoch 284/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2708 - mae: 0.2708 - val_loss: 0.1960 - val_mae: 0.1960
# Epoch 285/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2354 - mae: 0.2354 - val_loss: 0.2603 - val_mae: 0.2603
# Epoch 286/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2764 - mae: 0.2764 - val_loss: 0.1895 - val_mae: 0.1895
# Epoch 287/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2512 - mae: 0.2512 - val_loss: 0.1907 - val_mae: 0.1907
# Epoch 288/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2374 - mae: 0.2374 - val_loss: 0.3082 - val_mae: 0.3082
# Epoch 289/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3199 - mae: 0.3199 - val_loss: 0.3137 - val_mae: 0.3137
# Epoch 290/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3408 - mae: 0.3408 - val_loss: 0.3056 - val_mae: 0.3056
# Epoch 291/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3059 - mae: 0.3059 - val_loss: 0.2826 - val_mae: 0.2826
# Epoch 292/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3163 - mae: 0.3163 - val_loss: 0.2153 - val_mae: 0.2153
# Epoch 293/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2596 - mae: 0.2596 - val_loss: 0.2123 - val_mae: 0.2123
# Epoch 294/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2246 - mae: 0.2246 - val_loss: 0.1990 - val_mae: 0.1990
# Epoch 295/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2352 - mae: 0.2352 - val_loss: 0.2138 - val_mae: 0.2138
# Epoch 296/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2404 - mae: 0.2404 - val_loss: 0.2101 - val_mae: 0.2101
# Epoch 297/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2814 - mae: 0.2814 - val_loss: 0.3116 - val_mae: 0.3116
# Epoch 298/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2865 - mae: 0.2865 - val_loss: 0.2629 - val_mae: 0.2629
# Epoch 299/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2596 - mae: 0.2596 - val_loss: 0.2023 - val_mae: 0.2023
# Epoch 300/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2498 - mae: 0.2498 - val_loss: 0.1994 - val_mae: 0.1994
# Epoch 301/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2510 - mae: 0.2510 - val_loss: 0.2909 - val_mae: 0.2909
# Epoch 302/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2645 - mae: 0.2645 - val_loss: 0.2154 - val_mae: 0.2154
# Epoch 303/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2129 - mae: 0.2129 - val_loss: 0.2381 - val_mae: 0.2381
# Epoch 304/1250
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2645 - mae: 0.2645 - val_loss: 0.2499 - val_mae: 0.2499
# Epoch 305/1250
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2700 - mae: 0.2700 - val_loss: 0.2414 - val_mae: 0.2414
# Epoch 306/1250
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2421 - mae: 0.2421 - val_loss: 0.2018 - val_mae: 0.2018
# Epoch 307/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2149 - mae: 0.2149 - val_loss: 0.1834 - val_mae: 0.1834
# Epoch 308/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2242 - mae: 0.2242 - val_loss: 0.1925 - val_mae: 0.1925
# Epoch 309/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2049 - mae: 0.2049 - val_loss: 0.1858 - val_mae: 0.1858
# Epoch 310/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2201 - mae: 0.2201 - val_loss: 0.1894 - val_mae: 0.1894
# Epoch 311/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2418 - mae: 0.2418 - val_loss: 0.3192 - val_mae: 0.3192
# Epoch 312/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2831 - mae: 0.2831 - val_loss: 0.2042 - val_mae: 0.2042
# Epoch 313/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2069 - mae: 0.2069 - val_loss: 0.2101 - val_mae: 0.2101
# Epoch 314/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2355 - mae: 0.2355 - val_loss: 0.2385 - val_mae: 0.2385
# Epoch 315/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2541 - mae: 0.2541 - val_loss: 0.2288 - val_mae: 0.2288
# Epoch 316/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2761 - mae: 0.2761 - val_loss: 0.2336 - val_mae: 0.2336
# Epoch 317/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2327 - mae: 0.2327 - val_loss: 0.2184 - val_mae: 0.2184
# Epoch 318/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2617 - mae: 0.2617 - val_loss: 0.3207 - val_mae: 0.3207
# Epoch 319/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3040 - mae: 0.3040 - val_loss: 0.2141 - val_mae: 0.2141
# Epoch 320/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2847 - mae: 0.2847 - val_loss: 0.3203 - val_mae: 0.3203
# Epoch 321/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3216 - mae: 0.3216 - val_loss: 0.2188 - val_mae: 0.2188
# Epoch 322/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2892 - mae: 0.2892 - val_loss: 0.3030 - val_mae: 0.3030
# Epoch 323/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2824 - mae: 0.2824 - val_loss: 0.1857 - val_mae: 0.1857
# Epoch 324/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2709 - mae: 0.2709 - val_loss: 0.2173 - val_mae: 0.2173
# Epoch 325/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2098 - mae: 0.2098 - val_loss: 0.1863 - val_mae: 0.1863
# Epoch 326/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1982 - mae: 0.1982 - val_loss: 0.2241 - val_mae: 0.2241
# Epoch 327/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2254 - mae: 0.2254 - val_loss: 0.2101 - val_mae: 0.2101
# Epoch 328/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2147 - mae: 0.2147 - val_loss: 0.2133 - val_mae: 0.2133
# Epoch 329/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2234 - mae: 0.2234 - val_loss: 0.1837 - val_mae: 0.1837
# Epoch 330/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2310 - mae: 0.2310 - val_loss: 0.3115 - val_mae: 0.3115
# Epoch 331/1250
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2667 - mae: 0.2667 - val_loss: 0.1795 - val_mae: 0.1795
# Epoch 332/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2083 - mae: 0.2083 - val_loss: 0.1899 - val_mae: 0.1899
# Epoch 333/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2153 - mae: 0.2153 - val_loss: 0.2411 - val_mae: 0.2411
# Epoch 334/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2334 - mae: 0.2334 - val_loss: 0.2069 - val_mae: 0.2069
# Epoch 335/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2098 - mae: 0.2098 - val_loss: 0.1860 - val_mae: 0.1860
# Epoch 336/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1954 - mae: 0.1954 - val_loss: 0.2088 - val_mae: 0.2088
# Epoch 337/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2502 - mae: 0.2502 - val_loss: 0.2517 - val_mae: 0.2517
# Epoch 338/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2573 - mae: 0.2573 - val_loss: 0.1802 - val_mae: 0.1802
# Epoch 339/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2530 - mae: 0.2530 - val_loss: 0.2029 - val_mae: 0.2029
# Epoch 340/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2499 - mae: 0.2499 - val_loss: 0.2935 - val_mae: 0.2935
# Epoch 341/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2655 - mae: 0.2655 - val_loss: 0.2779 - val_mae: 0.2779
# Epoch 342/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2707 - mae: 0.2707 - val_loss: 0.1942 - val_mae: 0.1942
# Epoch 343/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2345 - mae: 0.2345 - val_loss: 0.2457 - val_mae: 0.2457
# Epoch 344/1250
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2349 - mae: 0.2349 - val_loss: 0.2668 - val_mae: 0.2668
# Epoch 345/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2599 - mae: 0.2599 - val_loss: 0.1859 - val_mae: 0.1859
# Epoch 346/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2302 - mae: 0.2302 - val_loss: 0.1823 - val_mae: 0.1823
# Epoch 347/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2098 - mae: 0.2098 - val_loss: 0.2326 - val_mae: 0.2326
# Epoch 348/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2225 - mae: 0.2225 - val_loss: 0.2352 - val_mae: 0.2352
# Epoch 349/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2410 - mae: 0.2410 - val_loss: 0.2373 - val_mae: 0.2373
# Epoch 350/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2916 - mae: 0.2916 - val_loss: 0.1846 - val_mae: 0.1846
# Epoch 351/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3109 - mae: 0.3109 - val_loss: 0.3348 - val_mae: 0.3348
# Epoch 352/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3334 - mae: 0.3334 - val_loss: 0.3641 - val_mae: 0.3641
# Epoch 353/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4442 - mae: 0.4442 - val_loss: 0.3685 - val_mae: 0.3685
# Epoch 354/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3782 - mae: 0.3782 - val_loss: 0.4660 - val_mae: 0.4660
# Epoch 355/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4131 - mae: 0.4131 - val_loss: 0.5696 - val_mae: 0.5696
# Epoch 356/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6373 - mae: 0.6373 - val_loss: 0.2991 - val_mae: 0.2991
# Epoch 357/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5576 - mae: 0.5576 - val_loss: 0.5093 - val_mae: 0.5093
# Epoch 358/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4781 - mae: 0.4781 - val_loss: 0.2974 - val_mae: 0.2974
# Epoch 359/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3253 - mae: 0.3253 - val_loss: 0.2763 - val_mae: 0.2763
# Epoch 360/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3027 - mae: 0.3027 - val_loss: 0.2786 - val_mae: 0.2786
# Epoch 361/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2809 - mae: 0.2809 - val_loss: 0.2678 - val_mae: 0.2678
# Epoch 362/1250
# ...
# Epoch 1132/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0968 - mae: 0.0968 - val_loss: 0.1021 - val_mae: 0.1021
# Epoch 1133/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0914 - mae: 0.0914 - val_loss: 0.0761 - val_mae: 0.0761
# Epoch 1134/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1006 - mae: 0.1006 - val_loss: 0.0893 - val_mae: 0.0893
# Epoch 1135/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0980 - mae: 0.0980 - val_loss: 0.0601 - val_mae: 0.0601
# Epoch 1136/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0802 - mae: 0.0802 - val_loss: 0.1175 - val_mae: 0.1175
# Epoch 1137/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1063 - mae: 0.1063 - val_loss: 0.0773 - val_mae: 0.0773
# Epoch 1138/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0945 - mae: 0.0945 - val_loss: 0.0680 - val_mae: 0.0680
# Epoch 1139/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0868 - mae: 0.0868 - val_loss: 0.1054 - val_mae: 0.1054
# Epoch 1140/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0922 - mae: 0.0922 - val_loss: 0.0776 - val_mae: 0.0776
# Epoch 1141/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0928 - mae: 0.0928 - val_loss: 0.0634 - val_mae: 0.0634
# Epoch 1142/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0935 - mae: 0.0935 - val_loss: 0.1157 - val_mae: 0.1157
# Epoch 1143/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1126 - mae: 0.1126 - val_loss: 0.0946 - val_mae: 0.0946
# Epoch 1144/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0913 - mae: 0.0913 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 1145/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0900 - mae: 0.0900 - val_loss: 0.1114 - val_mae: 0.1114
# Epoch 1146/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0998 - mae: 0.0998 - val_loss: 0.1184 - val_mae: 0.1184
# Epoch 1147/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0888 - mae: 0.0888 - val_loss: 0.0753 - val_mae: 0.0753
# Epoch 1148/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1061 - mae: 0.1061 - val_loss: 0.0952 - val_mae: 0.0952
# Epoch 1149/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0902 - mae: 0.0902 - val_loss: 0.1066 - val_mae: 0.1066
# Epoch 1150/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0931 - mae: 0.0931 - val_loss: 0.0836 - val_mae: 0.0836
# Epoch 1151/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0896 - mae: 0.0896 - val_loss: 0.0531 - val_mae: 0.0531
# Epoch 1152/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0898 - mae: 0.0898 - val_loss: 0.1009 - val_mae: 0.1009
# Epoch 1153/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0937 - mae: 0.0937 - val_loss: 0.0611 - val_mae: 0.0611
# Epoch 1154/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1164 - mae: 0.1164 - val_loss: 0.0890 - val_mae: 0.0890
# Epoch 1155/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1250 - mae: 0.1250 - val_loss: 0.1436 - val_mae: 0.1436
# Epoch 1156/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1274 - mae: 0.1274 - val_loss: 0.1009 - val_mae: 0.1009
# Epoch 1157/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1072 - mae: 0.1072 - val_loss: 0.0640 - val_mae: 0.0640
# Epoch 1158/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1218 - mae: 0.1218 - val_loss: 0.1319 - val_mae: 0.1319
# Epoch 1159/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1381 - mae: 0.1381 - val_loss: 0.1299 - val_mae: 0.1299
# Epoch 1160/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1382 - mae: 0.1382 - val_loss: 0.1143 - val_mae: 0.1143
# Epoch 1161/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0996 - mae: 0.0996 - val_loss: 0.0945 - val_mae: 0.0945
# Epoch 1162/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1281 - mae: 0.1281 - val_loss: 0.1255 - val_mae: 0.1255
# Epoch 1163/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1164 - mae: 0.1164 - val_loss: 0.1012 - val_mae: 0.1012
# Epoch 1164/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1154 - mae: 0.1154 - val_loss: 0.0654 - val_mae: 0.0654
# Epoch 1165/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1566 - mae: 0.1566 - val_loss: 0.0849 - val_mae: 0.0849
# Epoch 1166/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1218 - mae: 0.1218 - val_loss: 0.1264 - val_mae: 0.1264
# Epoch 1167/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1231 - mae: 0.1231 - val_loss: 0.0784 - val_mae: 0.0784
# Epoch 1168/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1241 - mae: 0.1241 - val_loss: 0.0939 - val_mae: 0.0939
# Epoch 1169/1250
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1011 - mae: 0.1011 - val_loss: 0.1073 - val_mae: 0.1073
# Epoch 1170/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1196 - mae: 0.1196 - val_loss: 0.0712 - val_mae: 0.0712
# Epoch 1171/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1057 - mae: 0.1057 - val_loss: 0.0737 - val_mae: 0.0737
# Epoch 1172/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0968 - mae: 0.0968 - val_loss: 0.0968 - val_mae: 0.0968
# Epoch 1173/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0902 - mae: 0.0902 - val_loss: 0.0900 - val_mae: 0.0900
# Epoch 1174/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0869 - mae: 0.0869 - val_loss: 0.0570 - val_mae: 0.0570
# Epoch 1175/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0837 - mae: 0.0837 - val_loss: 0.0615 - val_mae: 0.0615
# Epoch 1176/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0746 - mae: 0.0746 - val_loss: 0.0620 - val_mae: 0.0620
# Epoch 1177/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0799 - mae: 0.0799 - val_loss: 0.0655 - val_mae: 0.0655
# Epoch 1178/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0737 - mae: 0.0737 - val_loss: 0.0775 - val_mae: 0.0775
# Epoch 1179/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0840 - mae: 0.0840 - val_loss: 0.0776 - val_mae: 0.0776
# Epoch 1180/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 1181/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0752 - mae: 0.0752 - val_loss: 0.0806 - val_mae: 0.0806
# Epoch 1182/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.0643 - val_mae: 0.0643
# Epoch 1183/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0783 - mae: 0.0783 - val_loss: 0.0653 - val_mae: 0.0653
# Epoch 1184/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0741 - mae: 0.0741 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 1185/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0804 - mae: 0.0804 - val_loss: 0.0733 - val_mae: 0.0733
# Epoch 1186/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0571 - val_mae: 0.0571
# Epoch 1187/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0961 - mae: 0.0961 - val_loss: 0.0943 - val_mae: 0.0943
# Epoch 1188/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1104 - mae: 0.1104 - val_loss: 0.1171 - val_mae: 0.1171
# Epoch 1189/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1038 - mae: 0.1038 - val_loss: 0.0853 - val_mae: 0.0853
# Epoch 1190/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0792 - mae: 0.0792 - val_loss: 0.0515 - val_mae: 0.0515
# Epoch 1191/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0784 - mae: 0.0784 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 1192/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0806 - mae: 0.0806 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 1193/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1080 - mae: 0.1080 - val_loss: 0.0591 - val_mae: 0.0591
# Epoch 1194/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1063 - mae: 0.1063 - val_loss: 0.1112 - val_mae: 0.1112
# Epoch 1195/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1205 - mae: 0.1205 - val_loss: 0.0729 - val_mae: 0.0729
# Epoch 1196/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1463 - mae: 0.1463 - val_loss: 0.0999 - val_mae: 0.0999
# Epoch 1197/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1258 - mae: 0.1258 - val_loss: 0.0792 - val_mae: 0.0792
# Epoch 1198/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1062 - mae: 0.1062 - val_loss: 0.1020 - val_mae: 0.1020
# Epoch 1199/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0938 - mae: 0.0938 - val_loss: 0.0895 - val_mae: 0.0895
# Epoch 1200/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0960 - mae: 0.0960 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 1201/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0890 - mae: 0.0890 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 1202/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0840 - mae: 0.0840 - val_loss: 0.0909 - val_mae: 0.0909
# Epoch 1203/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0904 - mae: 0.0904 - val_loss: 0.0856 - val_mae: 0.0856
# Epoch 1204/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0872 - mae: 0.0872 - val_loss: 0.0781 - val_mae: 0.0781
# Epoch 1205/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0821 - mae: 0.0821 - val_loss: 0.0743 - val_mae: 0.0743
# Epoch 1206/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0831 - mae: 0.0831 - val_loss: 0.0806 - val_mae: 0.0806
# Epoch 1207/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0899 - mae: 0.0899 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 1208/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0913 - mae: 0.0913 - val_loss: 0.0790 - val_mae: 0.0790
# Epoch 1209/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0872 - mae: 0.0872 - val_loss: 0.0712 - val_mae: 0.0712
# Epoch 1210/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0900 - mae: 0.0900 - val_loss: 0.0660 - val_mae: 0.0660
# Epoch 1211/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0749 - mae: 0.0749 - val_loss: 0.0866 - val_mae: 0.0866
# Epoch 1212/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0816 - mae: 0.0816 - val_loss: 0.0875 - val_mae: 0.0875
# Epoch 1213/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.0769 - val_mae: 0.0769
# Epoch 1214/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0676 - val_mae: 0.0676
# Epoch 1215/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0954 - mae: 0.0954 - val_loss: 0.0620 - val_mae: 0.0620
# Epoch 1216/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0921 - mae: 0.0921 - val_loss: 0.0952 - val_mae: 0.0952
# Epoch 1217/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0848 - mae: 0.0848 - val_loss: 0.0535 - val_mae: 0.0535
# Epoch 1218/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0725 - mae: 0.0725 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 1219/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0789 - mae: 0.0789 - val_loss: 0.0632 - val_mae: 0.0632
# Epoch 1220/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0908 - mae: 0.0908 - val_loss: 0.0570 - val_mae: 0.0570
# Epoch 1221/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0863 - mae: 0.0863 - val_loss: 0.1055 - val_mae: 0.1055
# Epoch 1222/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0874 - mae: 0.0874 - val_loss: 0.0557 - val_mae: 0.0557
# Epoch 1223/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0972 - mae: 0.0972 - val_loss: 0.0525 - val_mae: 0.0525
# Epoch 1224/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0712 - mae: 0.0712 - val_loss: 0.0557 - val_mae: 0.0557
# Epoch 1225/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0700 - mae: 0.0700 - val_loss: 0.0605 - val_mae: 0.0605
# Epoch 1226/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0783 - mae: 0.0783 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 1227/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0887 - mae: 0.0887 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 1228/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.0657 - val_mae: 0.0657
# Epoch 1229/1250
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0806 - mae: 0.0806 - val_loss: 0.0867 - val_mae: 0.0867
# Epoch 1230/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1014 - mae: 0.1014 - val_loss: 0.0643 - val_mae: 0.0643
# Epoch 1231/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0829 - mae: 0.0829 - val_loss: 0.0612 - val_mae: 0.0612
# Epoch 1232/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0791 - mae: 0.0791 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 1233/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0829 - mae: 0.0829 - val_loss: 0.0808 - val_mae: 0.0808
# Epoch 1234/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0851 - mae: 0.0851 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 1235/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0744 - mae: 0.0744 - val_loss: 0.0783 - val_mae: 0.0783
# Epoch 1236/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0757 - mae: 0.0757 - val_loss: 0.0902 - val_mae: 0.0902
# Epoch 1237/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0934 - mae: 0.0934 - val_loss: 0.1170 - val_mae: 0.1170
# Epoch 1238/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1163 - mae: 0.1163 - val_loss: 0.0660 - val_mae: 0.0660
# Epoch 1239/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1091 - mae: 0.1091 - val_loss: 0.0656 - val_mae: 0.0656
# Epoch 1240/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0953 - mae: 0.0953 - val_loss: 0.0973 - val_mae: 0.0973
# Epoch 1241/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0853 - mae: 0.0853 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 1242/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0785 - mae: 0.0785 - val_loss: 0.0601 - val_mae: 0.0601
# Epoch 1243/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0775 - mae: 0.0775 - val_loss: 0.0485 - val_mae: 0.0485
# Epoch 1244/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0812 - mae: 0.0812 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 1245/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0980 - mae: 0.0980 - val_loss: 0.0730 - val_mae: 0.0730
# Epoch 1246/1250
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0895 - val_mae: 0.0895
# Epoch 1247/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0847 - mae: 0.0847 - val_loss: 0.0769 - val_mae: 0.0769
# Epoch 1248/1250
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0934 - mae: 0.0934 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 1249/1250
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0748 - mae: 0.0748 - val_loss: 0.0671 - val_mae: 0.0671
# Epoch 1250/1250
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0980 - mae: 0.0980 - val_loss: 0.0863 - val_mae: 0.0863

# %%
from sklearn.metrics import mean_absolute_error

print(f"MAE on test data = {mean_absolute_error(y_test, wine_regressor.predict(x_test))}")
# Out:
# MAE on test data = 0.08630423930784066

# %% [markdown]
# ---
